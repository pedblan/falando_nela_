# %% [markdown]
# #### Consolida banco de dados ####
# **Consolida banco de dados em ../data/DiscursosSenadores.sqlite. Feito em 21 jan 2025**

# %%
import sqlite3
import os

# Caminho para o banco de dados
DB_PATH = "../../data/DiscursosSenadores.sqlite"

def adicionar_coluna_texto_integral(db_path):
    """Adiciona a coluna TextoIntegral no banco de dados, se não existir."""
    conexao = sqlite3.connect(db_path)
    cursor = conexao.cursor()

    try:
        cursor.execute("ALTER TABLE Discursos ADD COLUMN TextoIntegral TEXT")
        conexao.commit()
    except sqlite3.OperationalError:
        print("A coluna TextoIntegral já existe no banco de dados.")

    conexao.close()

def atualizar_texto_integral(db_path):
    """Atualiza a coluna TextoIntegral no banco de dados com o conteúdo dos arquivos de texto."""
    conexao = sqlite3.connect(db_path)
    cursor = conexao.cursor()

    cursor.execute("SELECT CodigoPronunciamento, CaminhoArquivo FROM discursos WHERE DownloadConcluido = 1")
    discursos = cursor.fetchall()

    for codigo, caminho_arquivo in discursos:
        if not caminho_arquivo or not os.path.exists(caminho_arquivo):
            continue

        try:
            with open(caminho_arquivo, "r", encoding="utf-8") as file:
                texto_integral = file.read()

            cursor.execute(
                """
                UPDATE Discursos
                SET TextoIntegral = ?
                WHERE CodigoPronunciamento = ?
                """,
                (texto_integral, codigo)
            )
        except Exception as e:
            print(f"Erro ao atualizar TextoIntegral para discurso {codigo}: {e}")

    conexao.commit()
    conexao.close()

if __name__ == "__main__":
    # Adiciona a coluna TextoIntegral ao banco de dados
    adicionar_coluna_texto_integral(DB_PATH)

    # Atualiza a coluna TextoIntegral com os conteúdos dos arquivos
    atualizar_texto_integral(DB_PATH)

    print("Atualização da coluna TextoIntegral concluída.")
# Out:
# Atualização da coluna TextoIntegral concluída.

# %% [markdown]
# *Atualizando o banco de dados, coluna TextoIntegral*

# %%
def atualizar_banco_de_dados(db_path, temp_json_path):
    """Atualiza o banco de dados com os textos e caminhos do JSON temporário."""
    with open(temp_json_path, "r", encoding="utf-8") as json_file:
        temp_results = json.load(json_file)

    conexao = sqlite3.connect(db_path)
    cursor = conexao.cursor()

    for codigo, dados in temp_results.items():
        try:
            cursor.execute(
                """
                UPDATE discursos
                SET TextoIntegral = ?, CaminhoArquivo = ?
                WHERE CodigoPronunciamento = ?
                """,
                (dados["TextoIntegral"], dados["CaminhoArquivo"], codigo)
            )
            print(f"Banco de dados atualizado para Código: {codigo}")
        except Exception as e:
            print(f"Erro ao atualizar banco de dados para Código {codigo}: {e}")

    conexao.commit()
    conexao.close()

DB_PATH = "../../data/DiscursosSenadores.sqlite"
TEMP_JSON_PATH = "./temp/transcricoes_temp.json"

atualizar_banco_de_dados(DB_PATH, TEMP_JSON_PATH)
# Out:
# Banco de dados atualizado para Código: 469534
# Banco de dados atualizado para Código: 469722
# Banco de dados atualizado para Código: 472065
# Banco de dados atualizado para Código: 469095
# Banco de dados atualizado para Código: 466166
# Banco de dados atualizado para Código: 480057
# Banco de dados atualizado para Código: 482047
# Banco de dados atualizado para Código: 469793
# Banco de dados atualizado para Código: 470201
# Banco de dados atualizado para Código: 469547
# Banco de dados atualizado para Código: 470192
# Banco de dados atualizado para Código: 463665
# Banco de dados atualizado para Código: 469107
# Banco de dados atualizado para Código: 469113
# Banco de dados atualizado para Código: 469729
# Banco de dados atualizado para Código: 469677
# Banco de dados atualizado para Código: 468424
# Banco de dados atualizado para Código: 482000

# %%
print("Tabela de discursos concluída")
# Out:
# Tabela de discursos concluída

# %% [markdown]
# *Incluir cargos nas tabelas de Senadores*

# %%
import re
import json
from xml.etree.ElementTree import fromstring

# Caminho para o arquivo de entrada e saída
arquivo_entrada = "../../data/senadores/cargos.xml"
arquivo_saida = "../../data/senadores/cargos_senadores.json"

# Ler o arquivo completo como texto
with open(arquivo_entrada, 'r', encoding='utf-8') as file:
    conteudo = file.read()

# Separar os blocos usando o padrão de comentário como delimitador
blocos = re.split(r'<!-- Senador: (\d+) -->', conteudo)

# A lista para armazenar os dados processados
dados_senadores = []

# Processar pares de código e XML
for i in range(1, len(blocos), 2):  # Começa do índice 1, pula de 2 em 2
    codigo_parlamentar = blocos[i]
    xml_conteudo = blocos[i + 1].strip()

    try:
        # Parsear o XML do bloco
        root = fromstring(xml_conteudo)

        # Extrair informações do senador
        parlamentar = root.find(".//Parlamentar")
        nome_senador = parlamentar.find("Nome").text if parlamentar.find("Nome") is not None else None

        # Processar os cargos
        cargos = []
        for cargo in parlamentar.findall(".//Cargo"):  # Localiza todos os elementos <Cargo>
            descricao_cargo = cargo.find("DescricaoCargo").text if cargo.find("DescricaoCargo") is not None else None
            data_inicio = cargo.find("DataInicio").text if cargo.find("DataInicio") is not None else None
            data_fim = cargo.find("DataFim").text if cargo.find("DataFim") is not None else None
            orgao = cargo.find("IdentificacaoComissao/NomeComissao").text if cargo.find("IdentificacaoComissao/NomeComissao") is not None else None
            id_cargo = cargo.find("IdCargo").text if cargo.find("IdCargo") is not None else None

            cargos.append({
                "DescricaoCargo": descricao_cargo,
                "DataInicio": data_inicio,
                "DataFim": data_fim,
                "Orgao": orgao,
                "IdCargo": id_cargo,
            })

        # Adicionar os dados do senador à lista
        dados_senadores.append({
            "CodigoParlamentar": codigo_parlamentar,
            "Nome": nome_senador,
            "Cargos": cargos
        })

    except Exception as e:
        print(f"Erro ao processar Senador {codigo_parlamentar}: {e}")

# Salvar os dados em um arquivo JSON
with open(arquivo_saida, 'w', encoding='utf-8') as json_file:
    json.dump(dados_senadores, json_file, ensure_ascii=False, indent=4)

print(f"Dados salvos em {arquivo_saida}")
# Out:
# Dados salvos em ../data/senadores/cargos_senadores.json

# %% [markdown]
# *Acrescentar ao banco de dados*

# %%
# Inserir os dados no banco de dados SQLite
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# Adicionar a coluna Orgao se não existir
cursor.execute("PRAGMA table_info(SenadoresCargos)")
colunas_existentes = [col[1] for col in cursor.fetchall()]

if "Orgao" not in colunas_existentes:
    cursor.execute("ALTER TABLE SenadoresCargos ADD COLUMN Orgao TEXT")
    print("Coluna 'Orgao' adicionada à tabela SenadoresCargos.")

# Inserir os dados do JSON na tabela
for senador in dados_senadores:
    for cargo in senador["Cargos"]:
        cursor.execute('''
        INSERT INTO SenadoresCargos (CodigoParlamentar, NomeCargo, DataInicio, DataFim, Orgao, IdCargo)
        VALUES (?, ?, ?, ?, ?)
        ''', (
            senador["CodigoParlamentar"],
            cargo["DescricaoCargo"],
            cargo["DataInicio"],
            cargo["DataFim"],
            cargo["Orgao"],
            cargo["IdCargo"]
        ))

# Confirmar e fechar a conexão
conn.commit()
conn.close()

print("Dados inseridos no banco de dados com sucesso.")
# Out:
# Dados inseridos no banco de dados com sucesso.

# %% [markdown]
# *Agora, fazer a mesma coisa com histórico acadêmico*

# %%
import re
import json
import sqlite3
from xml.etree.ElementTree import fromstring

# Caminho para os arquivos
arquivo_entrada = "../../data/senadores/historico_academico.xml"
arquivo_saida = "../../data/senadores/historico_academico.json"
banco_dados = "../../data/DiscursosSenadores.sqlite"

# Ler o arquivo completo como texto
with open(arquivo_entrada, 'r', encoding='utf-8') as file:
    conteudo = file.read()

# Separar os blocos usando o padrão de comentário como delimitador
blocos = re.split(r'<!-- Senador: (\d+) -->', conteudo)

# A lista para armazenar os dados processados
dados_historico = []

# Processar pares de código e XML
for i in range(1, len(blocos), 2):  # Começa do índice 1, pula de 2 em 2
    codigo_parlamentar = blocos[i]
    xml_conteudo = blocos[i + 1].strip()

    try:
        # Parsear o XML do bloco
        root = fromstring(xml_conteudo)

        # Extrair histórico acadêmico
        historico = []
        for curso in root.findall(".//Curso"):
            nome_curso = curso.find("NomeCurso").text if curso.find("NomeCurso") is not None else None
            nivel_curso = curso.find("NivelCurso").text if curso.find("NivelCurso") is not None else None
            instituicao = curso.find("InstituicaoEnsino").text if curso.find("InstituicaoEnsino") is not None else None
            ano_conclusao = curso.find("AnoConclusao").text if curso.find("AnoConclusao") is not None else None

            historico.append({
                "NomeCurso": nome_curso,
                "NivelCurso": nivel_curso,
                "InstituicaoEnsino": instituicao,
                "AnoConclusao": ano_conclusao
            })

        # Adicionar os dados do senador à lista
        dados_historico.append({
            "CodigoParlamentar": codigo_parlamentar,
            "Historico": historico
        })

    except Exception as e:
        print(f"Erro ao processar Senador {codigo_parlamentar}: {e}")

# Salvar os dados em um arquivo JSON
with open(arquivo_saida, 'w', encoding='utf-8') as json_file:
    json.dump(dados_historico, json_file, ensure_ascii=False, indent=4)

print(f"Dados salvos em {arquivo_saida}")
# Out:
# Dados salvos em ../../data/senadores/historico_academico.json

# %% [markdown]
# *Atualizar o banco de dados*

# %%
# Inserir os dados no banco de dados SQLite
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# Adicionar a tabela SenadoresHistoricoAcademico se não existir
cursor.execute('''
CREATE TABLE IF NOT EXISTS SenadoresHistoricoAcademico (
    IdHistoricoAcademico INTEGER PRIMARY KEY AUTOINCREMENT,
    CodigoParlamentar INTEGER,
    NomeCurso TEXT,
    NivelCurso TEXT,
    InstituicaoEnsino TEXT,
    AnoConclusao TEXT,
    FOREIGN KEY (CodigoParlamentar) REFERENCES Senadores (CodigoParlamentar)
)
''')

# Inserir os dados do JSON na tabela
for senador in dados_historico:
    for curso in senador["Historico"]:
        cursor.execute('''
        INSERT INTO SenadoresHistoricoAcademico (CodigoParlamentar, NomeCurso, NivelCurso, InstituicaoEnsino, AnoConclusao)
        VALUES (?, ?, ?, ?, ?)
        ''', (
            senador["CodigoParlamentar"],
            curso["NomeCurso"],
            curso["NivelCurso"],
            curso["InstituicaoEnsino"],
            curso["AnoConclusao"]
        ))

# Confirmar e fechar a conexão
conn.commit()
conn.close()

print("Dados inseridos no banco de dados com sucesso.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[25], line 21
#      19 for senador in dados_historico:
#      20     for curso in senador["Historico"]:
# ---> 21         cursor.execute('''
#      22         INSERT INTO SenadoresHistoricoAcademico (CodigoParlamentar, NomeCurso, NivelCurso, InstituicaoEnsino, AnoConclusao)
#      23         VALUES (?, ?, ?, ?, ?)
#      24         ''', (
#      25             senador["CodigoParlamentar"],
#      26             curso["NomeCurso"],
#      27             curso["NivelCurso"],
#      28             curso["InstituicaoEnsino"],
#      29             curso["AnoConclusao"]
#      30         ))
#      32 # Confirmar e fechar a conexão
#      33 conn.commit()
#
# OperationalError: database is locked

# %% [markdown]
# *Incluir lideranças*

# %%
import re
import json
import sqlite3
from xml.etree.ElementTree import fromstring, ElementTree

# Caminho para os arquivos
arquivo_entrada = "../../data/senadores/liderancas.xml"
arquivo_saida = "../../data/senadores/liderancas.json"
banco_dados = "../../data/DiscursosSenadores.sqlite"

# Ler o arquivo completo como texto
with open(arquivo_entrada, 'r', encoding='utf-8') as file:
    conteudo = file.read()

# Separar os blocos usando o padrão de comentário como delimitador
blocos = re.split(r'<!-- Senador: (\d+) -->', conteudo)

# A lista para armazenar os dados processados
dados_liderancas = []

# Processar pares de código e XML
for i in range(1, len(blocos), 2):  # Começa do índice 1, pula de 2 em 2
    codigo_parlamentar = blocos[i]
    xml_conteudo = blocos[i + 1].strip()

    try:
        # Debug: Mostrar os primeiros caracteres do XML para verificar o conteúdo
        print(f"Processando Senador {codigo_parlamentar}. Prévia do XML: {xml_conteudo[:100]}")

        # Parsear o XML do bloco
        root = fromstring(xml_conteudo)

        # Extrair lideranças
        liderancas = []
        parlamentar = root.find(".//Parlamentar")
        if parlamentar is not None:
            liderancas_element = parlamentar.find("Liderancas")
            if liderancas_element is not None:
                for lideranca in liderancas_element.findall("Lideranca"):
                    unidade_lideranca = lideranca.find("UnidadeLideranca")
                    descricao_tipo_lideranca = lideranca.find("DescricaoTipoLideranca")
                    data_inicio = lideranca.find("DataDesignacao")
                    data_fim = lideranca.find("DataFim")

                    # Adicionar os valores à lista
                    liderancas.append({
                        "UnidadeLideranca": unidade_lideranca.text if unidade_lideranca is not None else None,
                        "DescricaoTipoLideranca": descricao_tipo_lideranca.text if descricao_tipo_lideranca is not None else None,
                        "DataInicio": data_inicio.text if data_inicio is not None else None,
                        "DataFim": data_fim.text if data_fim is not None else None,
                    })

        # Adicionar os dados do senador à lista
        dados_liderancas.append({
            "CodigoParlamentar": codigo_parlamentar,
            "Liderancas": liderancas
        })

    except Exception as e:
        print(f"Erro ao processar Senador {codigo_parlamentar}: {e}")

# Salvar os dados em um arquivo JSON
with open(arquivo_saida, 'w', encoding='utf-8') as json_file:
    json.dump(dados_liderancas, json_file, ensure_ascii=False, indent=4)

print(f"Dados salvos em {arquivo_saida}")
# Out:
# Processando Senador 4981. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4815. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3622. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5140. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5672. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5982. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4610. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3651. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4527. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3433. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 845. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 846. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 945. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4988. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3363. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6358. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4869. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6366. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5967. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4837. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5529. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4897. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 118. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5150. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4516. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4891. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 715. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 751. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 551. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4983. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6009. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5164. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6350. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3432. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 391. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3642. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4979. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3823. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4639. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6011. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5559. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 111. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6336. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 704. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6295. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5936. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5990. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 13. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5991. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 470. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 611. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5973. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5108. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 739. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6337. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3881. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4895. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 475. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3398. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4877. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5197. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3395. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4529. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5132. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6335. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5998. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3637. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3830. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5199. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3360. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3399. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5996. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5637. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5178. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5793. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6021. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5906. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3412. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5537. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 16. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4721. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3400. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4994. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5976. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3777. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4767. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 17. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5902. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4642. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 707. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4969. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5898. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 394. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5718. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5531. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 20. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 22. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4780. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 612. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3552. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1189. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5953. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5740. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5540. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4525. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5917. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6345. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 2632. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6374. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4873. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3634. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 345. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5894. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4605. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3619. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 765. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3574. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3713. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3371. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4935. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 87. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4522. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3392. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 28. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3626. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5615. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 30. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6008. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5030. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4558. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5006. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5639. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6341. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 740. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5008. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1179. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5100. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3373. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3578. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 613. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5076. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5385. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6015. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1754. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6010. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5004. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4937. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4770. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 35. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6340. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6351. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 581. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4545. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4531. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5627. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 36. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4792. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4533. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 38. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4776. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5895. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6342. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4990. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4885. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5350. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 40. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5849. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 878. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3595. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3361. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5112. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4547. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 615. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 47. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 90. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 950. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3394. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5166. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4537. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3593. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4774. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 916. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3652. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4541. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5972. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6369. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5929. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5158. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1249. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 415. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5533. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5156. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4811. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5979. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 53. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3374. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3695. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3579. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5926. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1186. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3643. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5585. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5002. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 151. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4575. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 643. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 631. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5557. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5666. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5376. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 742. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3366. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 285. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4788. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 86. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4535. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 105. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5422. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5942. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6304. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6019. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5908. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1023. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 59. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4998. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 527. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5000. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6362. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 670. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6027. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 952. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4539. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3364. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5997. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5985. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3644. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 63. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3648. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5281. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4961. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 64. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6006. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5525. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5924. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 66. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1210. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5523. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3393. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5018. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5617. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3397. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5927. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3741. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5020. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4549. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1169. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 825. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 374. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5116. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 68. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5010. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4927. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4606. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5502. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5971. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5386. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5913. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1206. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 2207. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 69. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5012. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5072. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5182. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3639. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5236. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3580. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 70. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5207. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3868. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5561. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 635. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5635. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5892. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3631. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5052. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 72. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 677. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5905. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5732. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4593. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5110. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4694. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5352. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 73. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 74. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5322. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 456. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4543. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6363. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 2331. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3359. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4893. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5621. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3646. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5038. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3645. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 735. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6331. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5048. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3362. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3532. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5527. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6005. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4957. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5988. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5959. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3365. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4560. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3375. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5106. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3396. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5535. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 78. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 6338. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5736. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5619. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 982. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4949. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3372. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3629. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5899. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 558. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5748. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4763. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4786. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4645. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1176. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 604. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5016. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 1173. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3583. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5411. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5070. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4772. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3811. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3597. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5783. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 3806. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5144. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 5184. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Processando Senador 4697. Prévia do XML: <?xml version='1.0' encoding='UTF-8'?>
# <LiderancaParlamentar xmlns:xsi='http://www.w3.org/2001/XMLSc
# Dados salvos em ../data/senadores/liderancas.json

# %% [markdown]
# *Insere lideranças no banco de dados*

# %%
import sqlite3
import json

# Caminho para o arquivo JSON e o banco de dados
arquivo_json = "../../data/senadores/liderancas.json"
banco_dados = "../../data/DiscursosSenadores.sqlite"

# Ler o arquivo JSON
with open(arquivo_json, 'r', encoding='utf-8') as json_file:
    dados_liderancas = json.load(json_file)

# Conectar ao banco de dados
conn = sqlite3.connect(banco_dados)
cursor = conn.cursor()

# Sobrescrever a tabela SenadoresLiderancas
cursor.execute('''
DROP TABLE IF EXISTS SenadoresLiderancas
''')

cursor.execute('''
CREATE TABLE SenadoresLiderancas (
    IdLideranca INTEGER PRIMARY KEY AUTOINCREMENT,
    CodigoParlamentar INTEGER,
    UnidadeLideranca TEXT,
    DescricaoTipoLideranca TEXT,
    DataInicio TEXT,
    DataFim TEXT,
    FOREIGN KEY (CodigoParlamentar) REFERENCES Senadores (CodigoParlamentar)
)
''')

# Inserir os dados do JSON na tabela
for senador in dados_liderancas:
    codigo_parlamentar = senador["CodigoParlamentar"]
    for lideranca in senador["Liderancas"]:
        cursor.execute('''
        INSERT INTO SenadoresLiderancas (CodigoParlamentar, UnidadeLideranca, DescricaoTipoLideranca, DataInicio, DataFim)
        VALUES (?, ?, ?, ?, ?)
        ''', (
            codigo_parlamentar,
            lideranca["UnidadeLideranca"],
            lideranca["DescricaoTipoLideranca"],
            lideranca["DataInicio"],
            lideranca["DataFim"]
        ))

# Confirmar e fechar a conexão
conn.commit()
conn.close()

print("Dados de lideranças inseridos no banco de dados com sucesso.")
# Out:
# Dados de lideranças inseridos no banco de dados com sucesso.

# %% [markdown]
# *Incluir comissões*

# %%
import sqlite3
import re
import json
from xml.etree.ElementTree import fromstring

# Caminhos para os arquivos
arquivo_xml = "../../data/senadores/comissoes.xml"
arquivo_json = "../../data/senadores/comissoes.json"
banco_dados = "../../data/DiscursosSenadores.sqlite"

# Ler o arquivo XML
with open(arquivo_xml, 'r', encoding='utf-8') as file:
    conteudo = file.read()

# Separar os blocos usando o padrão de comentário como delimitador
blocos = re.split(r'<!-- Senador: (\d+) -->', conteudo)

# A lista para armazenar os dados processados
dados_comissoes = []

# Processar pares de código e XML
for i in range(1, len(blocos), 2):  # Começa do índice 1, pula de 2 em 2
    codigo_parlamentar = blocos[i]
    xml_conteudo = blocos[i + 1].strip()

    try:
        # Parsear o XML do bloco
        root = fromstring(xml_conteudo)

        # Extrair as comissões
        comissoes = []
        comissoes_element = root.find(".//MembroComissoes")
        if comissoes_element is not None:
            for comissao in comissoes_element.findall("Comissao"):
                identificacao = comissao.find("IdentificacaoComissao")
                sigla_comissao = identificacao.find("SiglaComissao") if identificacao is not None else None
                nome_comissao = identificacao.find("NomeComissao") if identificacao is not None else None
                descricao_participacao = comissao.find("DescricaoParticipacao")
                data_inicio = comissao.find("DataInicio")
                data_fim = comissao.find("DataFim")

                # Adicionar os valores à lista
                comissoes.append({
                    "SiglaComissao": sigla_comissao.text if sigla_comissao is not None else None,
                    "NomeComissao": nome_comissao.text if nome_comissao is not None else None,
                    "DescricaoParticipacao": descricao_participacao.text if descricao_participacao is not None else None,
                    "DataInicio": data_inicio.text if data_inicio is not None else None,
                    "DataFim": data_fim.text if data_fim is not None else None,
                })

        # Adicionar os dados do senador à lista
        dados_comissoes.append({
            "CodigoParlamentar": codigo_parlamentar,
            "Comissoes": comissoes
        })

    except Exception as e:
        print(f"Erro ao processar Senador {codigo_parlamentar}: {e}")

# Salvar os dados em um arquivo JSON
with open(arquivo_json, 'w', encoding='utf-8') as json_file:
    json.dump(dados_comissoes, json_file, ensure_ascii=False, indent=4)

print(f"Dados salvos em {arquivo_json}")
# Out:
# Dados salvos em ../data/senadores/comissoes.json

# %% [markdown]
# *Inserir comissões no banco de dados*

# %%
# Conectar ao banco de dados
conn = sqlite3.connect(banco_dados)
cursor = conn.cursor()

# Sobrescrever a tabela SenadoresComissoes
cursor.execute('''
DROP TABLE IF EXISTS SenadoresComissoes
''')

cursor.execute('''
CREATE TABLE SenadoresComissoes (
    IdComissao INTEGER PRIMARY KEY AUTOINCREMENT,
    CodigoParlamentar INTEGER,
    SiglaComissao TEXT,
    NomeComissao TEXT,
    DescricaoParticipacao TEXT,
    DataInicio TEXT,
    DataFim TEXT,
    FOREIGN KEY (CodigoParlamentar) REFERENCES Senadores (CodigoParlamentar)
)
''')

# Inserir os dados do JSON na tabela
for senador in dados_comissoes:
    codigo_parlamentar = senador["CodigoParlamentar"]
    for comissao in senador["Comissoes"]:
        cursor.execute('''
        INSERT INTO SenadoresComissoes (CodigoParlamentar, SiglaComissao, NomeComissao, DescricaoParticipacao, DataInicio, DataFim)
        VALUES (?, ?, ?, ?, ?, ?)
        ''', (
            codigo_parlamentar,
            comissao["SiglaComissao"],
            comissao["NomeComissao"],
            comissao["DescricaoParticipacao"],
            comissao["DataInicio"],
            comissao["DataFim"]
        ))

# Confirmar e fechar a conexão
conn.commit()
conn.close()

print("Dados de comissões inseridos no banco de dados com sucesso.")
# Out:
# Dados de comissões inseridos no banco de dados com sucesso.

# %% [markdown]
# *Agora, filiações.*

# %%
import sqlite3
import re
import json
from xml.etree.ElementTree import fromstring

# Caminhos para os arquivos
arquivo_xml = "../../data/senadores/filiacoes.xml"
arquivo_json = "../../data/senadores/filiacoes.json"
banco_dados = "../../data/DiscursosSenadores.sqlite"

# Ler o arquivo XML
with open(arquivo_xml, 'r', encoding='utf-8') as file:
    conteudo = file.read()

# Separar os blocos usando o padrão de comentário como delimitador
blocos = re.split(r'<!-- Senador: (\d+) -->', conteudo)

# A lista para armazenar os dados processados
dados_filiacoes = []

# Processar pares de código e XML
for i in range(1, len(blocos), 2):  # Começa do índice 1, pula de 2 em 2
    codigo_parlamentar = blocos[i]
    xml_conteudo = blocos[i + 1].strip()

    try:
        # Parsear o XML do bloco
        root = fromstring(xml_conteudo)

        # Extrair as filiações
        filiacoes = []
        filiacoes_element = root.find(".//Filiacoes")
        if filiacoes_element is not None:
            for filiacao in filiacoes_element.findall("Filiacao"):
                partido = filiacao.find("Partido")
                sigla_partido = partido.find("SiglaPartido") if partido is not None else None
                nome_partido = partido.find("NomePartido") if partido is not None else None
                data_filiacao = filiacao.find("DataFiliacao")

                # Adicionar os valores à lista
                filiacoes.append({
                    "SiglaPartido": sigla_partido.text if sigla_partido is not None else None,
                    "NomePartido": nome_partido.text if nome_partido is not None else None,
                    "DataFiliacao": data_filiacao.text if data_filiacao is not None else None,
                })

        # Adicionar os dados do senador à lista
        dados_filiacoes.append({
            "CodigoParlamentar": codigo_parlamentar,
            "Filiacoes": filiacoes
        })

    except Exception as e:
        print(f"Erro ao processar Senador {codigo_parlamentar}: {e}")

# Salvar os dados em um arquivo JSON
with open(arquivo_json, 'w', encoding='utf-8') as json_file:
    json.dump(dados_filiacoes, json_file, ensure_ascii=False, indent=4)

print(f"Dados salvos em {arquivo_json}")
# Out:
# Dados salvos em ../data/senadores/filiacoes.json

# %% [markdown]
# *Inserir filiações no banco de dados*

# %%
# Conectar ao banco de dados
conn = sqlite3.connect(banco_dados)
cursor = conn.cursor()

# Sobrescrever a tabela SenadoresFiliacoes
cursor.execute('''
DROP TABLE IF EXISTS SenadoresFiliacoes
''')

cursor.execute('''
CREATE TABLE SenadoresFiliacoes (
    IdFiliacao INTEGER PRIMARY KEY AUTOINCREMENT,
    CodigoParlamentar INTEGER,
    SiglaPartido TEXT,
    NomePartido TEXT,
    DataFiliacao TEXT,
    FOREIGN KEY (CodigoParlamentar) REFERENCES Senadores (CodigoParlamentar)
)
''')

# Inserir os dados do JSON na tabela
for senador in dados_filiacoes:
    codigo_parlamentar = senador["CodigoParlamentar"]
    for filiacao in senador["Filiacoes"]:
        cursor.execute('''
        INSERT INTO SenadoresFiliacoes (CodigoParlamentar, SiglaPartido, NomePartido, DataFiliacao)
        VALUES (?, ?, ?, ?)
        ''', (
            codigo_parlamentar,
            filiacao["SiglaPartido"],
            filiacao["NomePartido"],
            filiacao["DataFiliacao"]
        ))

# Confirmar e fechar a conexão
conn.commit()
conn.close()

print("Dados de filiações inseridos no banco de dados com sucesso.")
# Out:
# Dados de filiações inseridos no banco de dados com sucesso.

# %% [markdown]
# ## Banco de dados DiscursosSenadores.sqlite concluído! ##

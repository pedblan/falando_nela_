# %% [markdown]
# ### 1. Produzir embeddings ###
# #### (só rodar uma vez!) ####

# %%
import sqlite3
import os

try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/falando_nela_v2/src')
    print("Current working directory (Colab):", os.getcwd())
else:
  print("Current working directory (not Colab):", os.getcwd())
DB_PATH = "../data/DiscursosSenadores.sqlite"
conn = sqlite3.connect(DB_PATH)
# Out:
# Mounted at /content/drive
# Current working directory (Colab): /content/drive/MyDrive/falando_nela_v2/src

# %%
# !pip install faiss-cpu langchain-openai langchain-community
from pesquisa import pesquisa_semantica
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.2 MB/s eta 0:00:00
# ...

# %%
print("🔄 Carregando dados do banco...")
dados = pesquisa_semantica.carregar_dados()
print("🔄 Criando índices FAISS...")
# Out:
# 🔄 Carregando dados do banco...
# 🔄 Criando índices FAISS...

# %%
pesquisa_semantica.criar_index_faiss(dados)
# Out:
# {'SumarioConstituicao': <faiss.swigfaiss_avx2.IndexFlatIP; proxy of <Swig Object of type 'faiss::IndexFlatIP *' at 0x781f5657adf0> >,
#  'TrechosConstituicao': <faiss.swigfaiss_avx2.IndexFlatIP; proxy of <Swig Object of type 'faiss::IndexFlatIP *' at 0x781f56571b30> >,
#  'NovaConstituinteOuConstituicao_trecho': <faiss.swigfaiss_avx2.IndexFlatIP; proxy of <Swig Object of type 'faiss::IndexFlatIP *' at 0x781f7ff37600> >}

# %% [markdown]
# Colunas disponíveis:
# - "SumarioConstituicao"
# - "TrechosConstituicao"
# - "NovaConstituinteOuConstituicao_trecho"
# todas da tabela DiscursosAnalises

# %% [markdown]
# ### 2. Buscar no FAISS e salvar pesquisa no banco de dados ###

# %%
# Exemplo de busca
import pandas as pd
query = 'A Constituição de 1988 é a base da democracia.'
coluna = 'SumarioConstituicao'
palavra_chave = "base_democracia"
resultados = pesquisa_semantica.buscar_no_faiss(query, coluna, palavra_chave)
pesquisa_semantica.salvar_banco_de_dados(resultados)
resultados
# Out:
# ✅ Resultados salvos com sucesso no banco de dados!
#        CodigoPronunciamento  Similaridade_base_democracia
# 0                    368423                      0.734892
# 1                    400129                      0.726794
# 2                    424559                      0.723762
# 3                    401125                      0.723609
# 4                    409303                      0.720115
# ...                     ...                           ...
# 67344                366335                      0.062467
# 67345                366334                      0.062467
# 67346                366332                      0.062467
# 67347                366330                      0.062467
# 67348                366328                      0.062467
#
# [67349 rows x 2 columns]

# %%
# Exemplo de busca
import pandas as pd
query = 'A Constituição de 1988 prejudica a economia.'
coluna = 'SumarioConstituicao'
palavra_chave = "prejudica_economia"
resultados = pesquisa_semantica.buscar_no_faiss(query, coluna, palavra_chave)
pesquisa_semantica.salvar_banco_de_dados(resultados)
resultados
# Out:
# ✅ Resultados salvos com sucesso no banco de dados!
#        CodigoPronunciamento  Similaridade_prejudica_economia
# 0                    420943                         0.697641
# 1                    385763                         0.694967
# 2                    502166                         0.682210
# 3                    370087                         0.681159
# 4                    449597                         0.669183
# ...                     ...                              ...
# 67344                366335                         0.013557
# 67345                366334                         0.013557
# 67346                366332                         0.013557
# 67347                366330                         0.013557
# 67348                366328                         0.013557
#
# [67349 rows x 2 columns]

# %%
# Exemplo de busca
import pandas as pd
query = 'A Constituição de 1988 está ultrapassada.'
coluna = 'SumarioConstituicao'
palavra_chave = "ultrapassada"
resultados = pesquisa_semantica.buscar_no_faiss(query, coluna, palavra_chave)
pesquisa_semantica.salvar_banco_de_dados(resultados)
resultados
# Out:
# ✅ Resultados salvos com sucesso no banco de dados!
#        CodigoPronunciamento  Similaridade_ultrapassada
# 0                    373619                   0.656588
# 1                    444043                   0.640806
# 2                    395987                   0.624325
# 3                    417191                   0.619277
# 4                    388112                   0.615341
# ...                     ...                        ...
# 67344                366335                   0.037343
# 67345                366334                   0.037343
# 67346                366332                   0.037343
# 67347                366330                   0.037343
# 67348                366328                   0.037343
#
# [67349 rows x 2 columns]

# %%
# Exemplo de busca
import pandas as pd
query = 'O Governo não respeita a Constituição de 1988.'
coluna = 'SumarioConstituicao'
palavra_chave = "governo_nao_respeita"
resultados = pesquisa_semantica.buscar_no_faiss(query, coluna, palavra_chave)
pesquisa_semantica.salvar_banco_de_dados(resultados)
resultados
# Out:
# ✅ Resultados salvos com sucesso no banco de dados!
#        CodigoPronunciamento  Similaridade_governo_nao_respeita
# 0                    467941                           0.633026
# 1                    457572                           0.628919
# 2                    396734                           0.627747
# 3                    410915                           0.623124
# 4                    433011                           0.619459
# ...                     ...                                ...
# 67344                366335                           0.059078
# 67345                366334                           0.059078
# 67346                366332                           0.059078
# 67347                366330                           0.059078
# 67348                366328                           0.059078
#
# [67349 rows x 2 columns]

# %%
# Exemplo de busca
import pandas as pd
query = 'A Câmara dos Deputados não respeita a Constituição de 1988.'
coluna = 'SumarioConstituicao'
palavra_chave = "camara_nao_respeita"
resultados = pesquisa_semantica.buscar_no_faiss(query, coluna, palavra_chave)
pesquisa_semantica.salvar_banco_de_dados(resultados)
resultados
# Out:
# ✅ Resultados salvos com sucesso no banco de dados!
#        CodigoPronunciamento  Similaridade_camara_nao_respeita
# 0                    396835                          0.593071
# 1                    509693                          0.588841
# 2                    498341                          0.587741
# 3                    419612                          0.583734
# 4                    400024                          0.583234
# ...                     ...                               ...
# 67344                366335                          0.053512
# 67345                366334                          0.053512
# 67346                366332                          0.053512
# 67347                366330                          0.053512
# 67348                366328                          0.053512
#
# [67349 rows x 2 columns]

# %%
# Exemplo de busca
import pandas as pd
query = 'O Supremo Tribunal Federal (STF) não respeita a Constituição de 1988.'
coluna = 'SumarioConstituicao'
palavra_chave = "supremo_nao_respeita"
resultados = pesquisa_semantica.buscar_no_faiss(query, coluna, palavra_chave)
pesquisa_semantica.salvar_banco_de_dados(resultados)
resultados
# Out:
# ✅ Resultados salvos com sucesso no banco de dados!
#        CodigoPronunciamento  Similaridade_supremo_nao_respeita
# 0                    506137                           0.649702
# 1                    505343                           0.647301
# 2                    497754                           0.645757
# 3                    500496                           0.643454
# 4                    504207                           0.642508
# ...                     ...                                ...
# 67344                366335                           0.067522
# 67345                366334                           0.067522
# 67346                366332                           0.067522
# 67347                366330                           0.067522
# 67348                366328                           0.067522
#
# [67349 rows x 2 columns]

# %%
# Exemplo de busca
import pandas as pd
query = 'Ninguém respeita a Constituição de 1988.'
coluna = 'SumarioConstituicao'
palavra_chave = "ninguem_respeita"
resultados = pesquisa_semantica.buscar_no_faiss(query, coluna, palavra_chave)
pesquisa_semantica.salvar_banco_de_dados(resultados)
resultados
# Out:
# ✅ Resultados salvos com sucesso no banco de dados!
#        CodigoPronunciamento  Similaridade_ninguem_respeita
# 0                    508289                       0.636483
# 1                    502978                       0.632329
# 2                    507528                       0.631229
# 3                    503831                       0.626026
# 4                    510581                       0.625545
# ...                     ...                            ...
# 67344                366335                       0.060366
# 67345                366334                       0.060366
# 67346                366332                       0.060366
# 67347                366330                       0.060366
# 67348                366328                       0.060366
#
# [67349 rows x 2 columns]

# %%
# Exemplo de busca
import pandas as pd
query = 'Precisamos convocar uma nova Constituinte.'
coluna = 'SumarioConstituicao'
palavra_chave = "nova_constituinte"
resultados = pesquisa_semantica.buscar_no_faiss(query, coluna, palavra_chave)
pesquisa_semantica.salvar_banco_de_dados(resultados)
resultados
# Out:
# ✅ Resultados salvos com sucesso no banco de dados!
#        CodigoPronunciamento  Similaridade_nova_constituinte
# 0                    383163                        0.641677
# 1                    381362                        0.631065
# 2                    408459                        0.630296
# 3                    383092                        0.629942
# 4                    381363                        0.625894
# ...                     ...                             ...
# 67344                366335                        0.079220
# 67345                366334                        0.079220
# 67346                366332                        0.079220
# 67347                366330                        0.079220
# 67348                366328                        0.079220
#
# [67349 rows x 2 columns]

# %% [markdown]
# ### Carregar arquivo ###

# %%
CAMINHO_BANCO_DE_DADOS = '../../data/dados_analisados_2025-05-03.xlsx'

# %% [markdown]
# ### Verificar pendências ###

# %%
from analise_corpus_todo.pendencias import identificar

pendencias = identificar(CAMINHO_BANCO_DE_DADOS)
# Out:
# Quantidade de pendências: 2170

# %% [markdown]
# #### Analise LLM ####

# %%
import pandas as pd
df_discursos = pd.read_excel(CAMINHO_BANCO_DE_DADOS, sheet_name='Discursos')

# %%
if 'CodigoPronunciamento' in df_discursos.columns:
    df_pendencias = df_discursos[df_discursos['CodigoPronunciamento'].isin(pendencias)]
else:
    raise ValueError("'CodigoPronunciamento' não encontrado em df_discursos.")

# %%
df_analise_corpus_todo = pd.read_excel(CAMINHO_BANCO_DE_DADOS, sheet_name='AnaliseCorpusTodo')

# %%
from analise_corpus_todo.analisar_com_llm import analisar_texto_arg_linguistica, analisar_texto_sumarizacao_classificacao
from analise_corpus_todo.prompts import instrucao_analise_arg_linguistica, instrucao_sumario_classificacao

# %% [markdown]
# #### Sumário

# %%
import json
import tempfile
import os
import pandas as pd
import numpy as np

# Substituir os NaN em df_pendencias antes da iteração
df_pendencias = df_pendencias.fillna("")  # Substituir NaN por espaço ("")
print("Substituídos todos os NaN por espaço no DataFrame `df_pendencias`.")

# Definir o caminho do arquivo temporário
temp_file_path = 'resultados_parciais.json'

# Inicializar dicionário para armazenamento dos resultados
if os.path.exists(temp_file_path):
    print(f"Arquivo parcial encontrado: {temp_file_path}. Carregando progresso anterior...")
    with open(temp_file_path, 'r', encoding='utf-8') as temp_file:
        try:
            resultados = json.load(temp_file)
            print("Progresso carregado com sucesso!")
        except json.JSONDecodeError:
            print(f"Erro ao carregar o arquivo JSON parcial {temp_file_path}. Inicializando novo progresso.")
            resultados = {}
else:
    print("Nenhum arquivo parcial encontrado. Iniciando novo processamento...")
    resultados = {}


# Função auxiliar para normalizar valores inválidos no JSON
def json_safe(data):
    if isinstance(data, dict):
        return {k: json_safe(v) for k, v in data.items()}
    elif isinstance(data, list):
        return [json_safe(x) for x in data]
    elif isinstance(data, float):
        # Normalizar valores float inválidos (NaN, Inf, -Inf)
        if data != data or data == float("inf") or data == float("-inf"):
            return None
        return data
    else:
        return data


# Iterar sobre cada linha do DataFrame com print statements e salvar progresso
salvar_a_cada = 5  # Número de iterações antes de salvar
contador = 0  # Contador de progresso

total_pendencias = len(df_pendencias)
print(f"Iniciando o processamento de {total_pendencias} pendências...")

for index, linha in df_pendencias[['CodigoPronunciamento', 'TextoIntegral']].iterrows():
    codigo = linha['CodigoPronunciamento']
    texto = linha['TextoIntegral']

    # Checar se já foi processado
    if codigo in resultados:
        print(f"[{index}] Código {codigo} já processado. Pulando para o próximo...")
        continue

    print(f"[{index}] Processando código {codigo}...")

    # Aplicar a função analisar_texto_sumarizacao_classificacao
    try:
        analise = analisar_texto_sumarizacao_classificacao(codigo, instrucao_sumario_classificacao, texto)
    except Exception as e:
        print(f"Erro ao processar o código {codigo}: {e}")
        analise = "{}"  # Valor padrão em caso de falha na função

    # Tentar converter a string JSON em um dicionário
    try:
        analise_dict = json.loads(analise)  # Fazer parsing do JSON para dicionário
    except json.JSONDecodeError:
        print(f"Erro ao parsear JSON para o código {codigo}. Ignorando e continuando...")
        analise_dict = {}

    # Normalizar valores inválidos no JSON
    analise_dict = json_safe(analise_dict)

    # Selecionar apenas as chaves desejadas para salvar no JSON
    analise_filtrada = {
        'SentimentoGeral': analise_dict.get('SentimentoGeral'),
        'SentimentoConstituicao': analise_dict.get('SentimentoConstituicao'),
        'SumarioConstituicao': analise_dict.get('SumarioConstituicao'),
        'TrechosConstituicao': analise_dict.get('TrechosConstituicao'),
        'NovaConstituinteOuConstituicao_resposta': analise_dict.get('NovaConstituinteOuConstituicao', {}).get(
            'resposta'),
        'NovaConstituinteOuConstituicao_trecho': analise_dict.get('NovaConstituinteOuConstituicao', {}).get('trecho')
    }

    # Guardar o dicionário no resultado final
    resultados[codigo] = analise_filtrada
    print(f"[{index}] Código {codigo} processado com sucesso.")

    # Incrementar o contador
    contador += 1

    # Salvar os resultados parcialmente a cada 5 iterações
    if contador % salvar_a_cada == 0:
        print(f"Salvando progresso após {contador} iterações no arquivo {temp_file_path}...")
        with open(temp_file_path, 'w', encoding='utf-8') as temp_file:
            json.dump(resultados, temp_file, ensure_ascii=False, indent=4)
        print(f"Progresso salvo com sucesso!")

# Salvar quaisquer dados restantes após concluir o loop
print(f"Salvando o progresso final no arquivo {temp_file_path}...")
with open(temp_file_path, 'w', encoding='utf-8') as temp_file:
    json.dump(resultados, temp_file, ensure_ascii=False, indent=4)

print("Processamento concluído. Resultados salvos com sucesso!")
# Out:
# Substituídos todos os NaN por espaço no DataFrame `df_pendencias`.
# Nenhum arquivo parcial encontrado. Iniciando novo processamento...
# Iniciando o processamento de 2170 pendências...
# [67349] Processando código 512328...
# [67349] Código 512328 processado com sucesso.
# [67350] Processando código 511720...
# [67350] Código 511720 processado com sucesso.
# [67351] Processando código 511641...
# [67351] Código 511641 processado com sucesso.
# [67352] Processando código 511622...
# [67352] Código 511622 processado com sucesso.
# [67353] Processando código 511550...
# [67353] Código 511550 processado com sucesso.
# Salvando progresso após 5 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [67354] Processando código 511539...
# [67354] Código 511539 processado com sucesso.
# [67355] Processando código 511529...
# [67355] Código 511529 processado com sucesso.
# [67356] Processando código 511505...
# [67356] Código 511505 processado com sucesso.
# [67357] Processando código 511490...
# [67357] Código 511490 processado com sucesso.
# [67358] Processando código 511440...
# [67358] Código 511440 processado com sucesso.
# Salvando progresso após 10 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [67359] Processando código 510691...
# [67359] Código 510691 processado com sucesso.
# [67360] Processando código 510652...
# [67360] Código 510652 processado com sucesso.
# [67361] Processando código 511145...
# [67361] Código 511145 processado com sucesso.
# [67362] Processando código 511122...
# [67362] Código 511122 processado com sucesso.
# [67363] Processando código 511072...
# [67363] Código 511072 processado com sucesso.
# Salvando progresso após 15 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [67364] Processando código 511375...
# [67364] Código 511375 processado com sucesso.
# [67365] Processando código 511352...
# [67365] Código 511352 processado com sucesso.
# [67366] Processando código 511317...
# [67366] Código 511317 processado com sucesso.
# [67367] Processando código 512180...
# [67367] Código 512180 processado com sucesso.
# [67368] Processando código 510774...
# [67368] Código 510774 processado com sucesso.
# Salvando progresso após 20 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [
iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [69484] Processando código 512645...
# [69484] Código 512645 processado com sucesso.
# [69485] Processando código 512529...
# [69485] Código 512529 processado com sucesso.
# [69486] Processando código 512480...
# [69486] Código 512480 processado com sucesso.
# [69487] Processando código 512257...
# [69487] Código 512257 processado com sucesso.
# [69488] Processando código 511915...
# [69488] Código 511915 processado com sucesso.
# Salvando progresso após 2140 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [69489] Processando código 511732...
# [69489] Código 511732 processado com sucesso.
# [69490] Processando código 510667...
# [69490] Código 510667 processado com sucesso.
# [69491] Processando código 511337...
# [69491] Código 511337 processado com sucesso.
# [69492] Processando código 511328...
# [69492] Código 511328 processado com sucesso.
# [69493] Processando código 511323...
# [69493] Código 511323 processado com sucesso.
# Salvando progresso após 2145 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [69494] Processando código 511320...
# [69494] Código 511320 processado com sucesso.
# [69495] Processando código 511303...
# [69495] Código 511303 processado com sucesso.
# [69496] Processando código 511281...
# [69496] Código 511281 processado com sucesso.
# [69497] Processando código 511250...
# [69497] Código 511250 processado com sucesso.
# [69498] Processando código 511170...
# [69498] Código 511170 processado com sucesso.
# Salvando progresso após 2150 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [69499] Processando código 511180...
# [69499] Código 511180 processado com sucesso.
# [69500] Processando código 511129...
# [69500] Código 511129 processado com sucesso.
# [69501] Processando código 511111...
# [69501] Código 511111 processado com sucesso.
# [69502] Processando código 511100...
# [69502] Código 511100 processado com sucesso.
# [69503] Processando código 511087...
# [69503] Código 511087 processado com sucesso.
# Salvando progresso após 2155 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [69504] Processando código 511082...
# [69504] Código 511082 processado com sucesso.
# [69505] Processando código 511044...
# [69505] Código 511044 processado com sucesso.
# [69506] Processando código 510971...
# [69506] Código 510971 processado com sucesso.
# [69507] Processando código 512037...
# [69507] Código 512037 processado com sucesso.
# [69508] Processando código 512443...
# [69508] Código 512443 processado com sucesso.
# Salvando progresso após 2160 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [69509] Processando código 512424...
# [69509] Código 512424 processado com sucesso.
# [69510] Processando código 512394...
# [69510] Código 512394 processado com sucesso.
# [69511] Processando código 512392...
# [69511] Código 512392 processado com sucesso.
# [69512] Processando código 512390...
# [69512] Código 512390 processado com sucesso.
# [69513] Processando código 510951...
# [69513] Código 510951 processado com sucesso.
# Salvando progresso após 2165 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# [69514] Processando código 511952...
# [69514] Código 511952 processado com sucesso.
# [69515] Processando código 512162...
# [69515] Código 512162 processado com sucesso.
# [69516] Processando código 512152...
# [69516] Código 512152 processado com sucesso.
# [69517] Processando código 512273...
# [69517] Código 512273 processado com sucesso.
# [69518] Processando código 512219...
# [69518] Código 512219 processado com sucesso.
# Salvando progresso após 2170 iterações no arquivo resultados_parciais.json...
# Progresso salvo com sucesso!
# Salvando o progresso final no arquivo resultados_parciais.json...
# Processamento concluído. Resultados salvos com sucesso!

# %% [markdown]
# ##### Análise linguística

# %%
import json
import tempfile
import os
import shutil
import pandas as pd

# Definir o caminho do arquivo de resultados parciais para `analisar_texto_arg_linguistica`
resultados_json = 'resultados_arg_linguistica.json'

# Inicializar ou carregar progresso anterior
if os.path.exists(resultados_json):
    print(f"Arquivo parcial encontrado: {resultados_json}. Carregando progresso anterior...")
    with open(resultados_json, 'r', encoding='utf-8') as json_file:
        try:
            resultados = json.load(json_file)
            print("Progresso carregado com sucesso!")
        except json.JSONDecodeError:
            print(f"Erro ao carregar o arquivo parcial {resultados_json}. Inicializando novo progresso.")
            resultados = {}
else:
    print("Nenhum arquivo parcial encontrado. Iniciando novo processamento...")
    resultados = {}


# Função auxiliar para normalizar valores inválidos no JSON
def json_safe(data):
    if isinstance(data, dict):
        return {k: json_safe(v) for k, v in data.items()}
    elif isinstance(data, list):
        return [json_safe(x) for x in data]
    elif isinstance(data, float):
        # Normalizar valores float inválidos (NaN, Inf, -Inf)
        if data != data or data == float("inf") or data == float("-inf"):
            return None
        return data
    else:
        return data


# Iterar sobre cada linha do DataFrame com print statements e salvar progresso incrementalmente
salvar_a_cada = 5  # Número de iterações antes de salvar
contador = 0  # Contador de progresso
total_pendencias = len(df_pendencias)
print(f"Iniciando o processamento de {total_pendencias} pendências com `analisar_texto_arg_linguistica`...")

for index, linha in df_pendencias[['CodigoPronunciamento', 'TextoIntegral']].iterrows():
    codigo = linha['CodigoPronunciamento']
    texto = linha['TextoIntegral']

    # Checar se já foi processado
    if codigo in resultados:
        print(f"[{index}] Código {codigo} já processado. Pulando para o próximo...")
        continue

    print(f"[{index}] Processando código {codigo} com `analisar_texto_arg_linguistica`...")

    # Aplicar a função analisar_texto_arg_linguistica
    try:
        analise = analisar_texto_arg_linguistica(codigo, instrucao_analise_arg_linguistica, texto)
    except Exception as e:
        print(f"Erro ao processar o código {codigo}: {e}")
        analise = "{}"  # Valor padrão em caso de falha na função

    # Tentar converter a string JSON em um dicionário
    try:
        analise_dict = json.loads(analise)  # Fazer parsing do JSON para dicionário
    except json.JSONDecodeError:
        print(f"Erro ao parsear JSON para o código {codigo}. Ignorando e continuando...")
        analise_dict = {}

    # Normalizar valores inválidos no JSON
    analise_dict = json_safe(analise_dict)

    # Adicionar os resultados normalizados ao dicionário final
    resultados[codigo] = analise_dict
    print(f"[{index}] Código {codigo} processado com sucesso.")

    # Incrementar o contador e salvar os resultados parcialmente
    contador += 1
    if contador % salvar_a_cada == 0:
        print(f"Salvando progresso após {contador} iterações no arquivo {resultados_json}...")
        with open(resultados_json, 'w', encoding='utf-8') as json_file:
            json.dump(resultados, json_file, ensure_ascii=False, indent=4)
        print(f"Progresso salvo com sucesso!")

# Salvar quaisquer dados restantes após concluir o loop
print(f"Salvando o progresso final no arquivo {resultados_json}...")
with open(resultados_json, 'w', encoding='utf-8') as json_file:
    json.dump(resultados, json_file, ensure_ascii=False, indent=4)
print("Processamento concluído. Resultados salvos com sucesso!")
# Out:
# Nenhum arquivo parcial encontrado. Iniciando novo processamento...
# Iniciando o processamento de 2170 pendências com `analisar_texto_arg_linguistica`...
# [67349] Processando código 512328 com `analisar_texto_arg_linguistica`...
# [67349] Código 512328 processado com sucesso.
# [67350] Processando código 511720 com `analisar_texto_arg_linguistica`...
# [67350] Código 511720 processado com sucesso.
# [67351] Processando código 511641 com `analisar_texto_arg_linguistica`...
# [67351] Código 511641 processado com sucesso.
# [67352] Processando código 511622 com `analisar_texto_arg_linguistica`...
# [67352] Código 511622 processado com sucesso.
# [67353] Processando código 511550 com `analisar_texto_arg_linguistica`...
# [67353] Código 511550 processado com sucesso.
# Salvando progresso após 5 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67354] Processando código 511539 com `analisar_texto_arg_linguistica`...
# [67354] Código 511539 processado com sucesso.
# [67355] Processando código 511529 com `analisar_texto_arg_linguistica`...
# [67355] Código 511529 processado com sucesso.
# [67356] Processando código 511505 com `analisar_texto_arg_linguistica`...
# [67356] Código 511505 processado com sucesso.
# [67357] Processando código 511490 com `analisar_texto_arg_linguistica`...
# [67357] Código 511490 processado com sucesso.
# [67358] Processando código 511440 com `analisar_texto_arg_linguistica`...
# [67358] Código 511440 processado com sucesso.
# Salvando progresso após 10 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67359] Processando código 510691 com `analisar_texto_arg_linguistica`...
# [67359] Código 510691 processado com sucesso.
# [67360] Processando código 510652 com `analisar_texto_arg_linguistica`...
# [67360] Código 510652 processado com sucesso.
# [67361] Processando código 511145 com `analisar_texto_arg_linguistica`...
# [67361] Código 511145 processado com sucesso.
# [67362] Processando código 511122 com `analisar_texto_arg_linguistica`...
# [67362] Código 511122 processado com sucesso.
# [67363] Processando código 511072 com `analisar_texto_arg_linguistica`...
# [67363] Código 511072 processado com sucesso.
# Salvando progresso após 15 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67364] Processando código 511375 com `analisar_texto_arg_linguistica`...
# [67364] Código 511375 processado com sucesso.
# [67365] Processando código 511352 com `analisar_texto_arg_linguistica`...
# [67365] Código 511352 processado com sucesso.
# [67366] Processando código 511317 com `analisar_texto_arg_linguistica`...
# [67366] Código 511317 processado com sucesso.
# [67367] Processando código 512180 com `analisar_texto_arg_linguistica`...
# [67367] Código 512180 processado com sucesso.
# [67368] Processando código 510774 com `analisar_texto_arg_linguistica`...
# [67368] Código 510774 processado com sucesso.
# Salvando progresso após 20 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67369] Processando código 510764 com `analisar_texto_arg_linguistica`...
# [67369] Código 510764 processado com sucesso.
# [67370] Processando código 510760 com `analisar_texto_arg_linguistica`...
# [67370] Código 510760 processado com sucesso.
# [67371] Processando código 510745 com `analisar_texto_arg_linguistica`...
# [67371] Código 510745 processado com sucesso.
# [67372] Processando código 510741 com `analisar_texto_arg_linguistica`...
# [67372] Código 510741 processado com sucesso.
# [67373] Processando código 510722 com `analisar_texto_arg_linguistica`...
# [67373] Código 510722 processado com sucesso.
# Salvando progresso após 25 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67374] Processando código 510715 com `analisar_texto_arg_linguistica`...
# [67374] Código 510715 processado com sucesso.
# [67375] Processando código 510713 com `analisar_texto_arg_linguistica`...
# [67375] Código 510713 processado com sucesso.
# [67376] Processando código 511359 com `analisar_texto_arg_linguistica`...
# [67376] Código 511359 processado com sucesso.
# [67377] Processando código 511333 com `analisar_texto_arg_linguistica`...
# [67377] Código 511333 processado com sucesso.
# [67378] Processando código 511201 com `analisar_texto_arg_linguistica`...
# [67378] Código 511201 processado com sucesso.
# Salvando progresso após 30 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67379] Processando código 511115 com `analisar_texto_arg_linguistica`...
# [67379] Código 511115 processado com sucesso.
# [67380] Processando código 511387 com `analisar_texto_arg_linguistica`...
# [67380] Código 511387 processado com sucesso.
# [67381] Processando código 511302 com `analisar_texto_arg_linguistica`...
# [67381] Código 511302 processado com sucesso.
# [67382] Processando código 511205 com `analisar_texto_arg_linguistica`...
# [67382] Código 511205 processado com sucesso.
# [67383] Processando código 511032 com `analisar_texto_arg_linguistica`...
# [67383] Código 511032 processado com sucesso.
# Salvando progresso após 35 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67384] Processando código 511014 com `analisar_texto_arg_linguistica`...
# [67384] Código 511014 processado com sucesso.
# [67385] Processando código 510985 com `analisar_texto_arg_linguistica`...
# [67385] Código 510985 processado com sucesso.
# [67386] Processando código 512523 com `analisar_texto_arg_linguistica`...
# [67386] Código 512523 processado com sucesso.
# [67387] Processando código 512395 com `analisar_texto_arg_linguistica`...
# [67387] Código 512395 processado com sucesso.
# [67388] Processando código 512373 com `analisar_texto_arg_linguistica`...
# [67388] Código 512373 processado com sucesso.
# Salvando progresso após 40 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67389] Processando código 512367 com `analisar_texto_arg_linguistica`...
# [67389] Código 512367 processado com sucesso.
# [67390] Processando código 512266 com `analisar_texto_arg_linguistica`...
# [67390] Código 512266 processado com sucesso.
# [67391] Processando código 512264 com `analisar_texto_arg_linguistica`...
# [67391] Código 512264 processado com sucesso.
# [67392] Processando código 511902 com `analisar_texto_arg_linguistica`...
# [67392] Código 511902 processado com sucesso.
# [67393] Processando código 510743 com `analisar_texto_arg_linguistica`...
# [67393] Código 510743 processado com sucesso.
# Salvando progresso após 45 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67394] Processando código 510720 com `analisar_texto_arg_linguistica`...
# [67394] Código 510720 processado com sucesso.
# [67395] Processando código 511020 com `analisar_texto_arg_linguistica`...
# [67395] Código 511020 processado com sucesso.
# [67396] Processando código 510956 com `analisar_texto_arg_linguistica`...
# [67396] Código 510956 processado com sucesso.
# [67397] Processando código 510936 com `analisar_texto_arg_linguistica`...
# [67397] Código 510936 processado com sucesso.
# [67398] Processando código 510888 com `analisar_texto_arg_linguistica`...
# [67398] Código 510888 processado com sucesso.
# Salvando progresso após 50 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67399] Processando código 512355 com `analisar_texto_arg_linguistica`...
# [67399] Código 512355 processado com sucesso.
# [67400] Processando código 512299 com `analisar_texto_arg_linguistica`...
# [67400] Código 512299 processado com sucesso.
# [67401] Processando código 512208 com `analisar_texto_arg_linguistica`...
# [67401] Código 512208 processado com sucesso.
# [67402] Processando código 511667 com `analisar_texto_arg_linguistica`...
# [67402] Código 511667 processado com sucesso.
# [67403] Processando código 511640 com `analisar_texto_arg_linguistica`...
# [67403] Código 511640 processado com sucesso.
# Salvando progresso após 55 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67404] Processando código 511625 com `analisar_texto_arg_linguistica`...
# [67404] Código 511625 processado com sucesso.
# [67405] Processando código 511621 com `analisar_texto_arg_linguistica`...
# [67405] Código 511621 processado com sucesso.
# [67406] Processando código 511549 com `analisar_texto_arg_linguistica`...
# [67406] Código 511549 processado com sucesso.
# [67407] Processando código 511528 com `analisar_texto_arg_linguistica`...
# [67407] Código 511528 processado com sucesso.
# [67408] Processando código 511504 com `analisar_texto_arg_linguistica`...
# [67408] Código 511504 processado com sucesso.
# Salvando progresso após 60 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67409] Processando código 511484 com `analisar_texto_arg_linguistica`...
# [67409] Código 511484 processado com sucesso.
# [67410] Processando código 511482 com `analisar_texto_arg_linguistica`...
# [67410] Código 511482 processado com sucesso.
# [67411] Processando código 511444 com `analisar_texto_arg_linguistica`...
# [67411] Código 511444 processado com sucesso.
# [67412] Processando código 510609 com `analisar_texto_arg_linguistica`...
# [67412] Código 510609 processado com sucesso.
# [67413] Processando código 511101 com `analisar_texto_arg_linguistica`...
# [67413] Código 511101 processado com sucesso.
# Salvando progresso após 65 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67414] Processando código 511057 com `analisar_texto_arg_linguistica`...
# [67414] Código 511057 processado com sucesso.
# [67415] Processando código 510885 com `analisar_texto_arg_linguistica`...
# [67415] Código 510885 processado com sucesso.
# [67416] Processando código 510881 com `analisar_texto_arg_linguistica`...
# [67416] Código 510881 processado com sucesso.
# [67417] Processando código 510450 com `analisar_texto_arg_linguistica`...
# [67417] Código 510450 processado com sucesso.
# [67418] Processando código 512001 com `analisar_texto_arg_linguistica`...
# [67418] Código 512001 processado com sucesso.
# Salvando progresso após 70 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67419] Processando código 511995 com `analisar_texto_arg_linguistica`...
# [67419] Código 511995 processado com sucesso.
# [67420] Processando código 512472 com `analisar_texto_arg_linguistica`...
# [67420] Código 512472 processado com sucesso.
# [67421] Processando código 512262 com `analisar_texto_arg_linguistica`...
# [67421] Código 512262 processado com sucesso.
# [67422] Processando código 511132 com `analisar_texto_arg_linguistica`...
# [67422] Código 511132 processado com sucesso.
# [67423] Processando código 511058 com `analisar_texto_arg_linguistica`...
# [67423] Código 511058 processado com sucesso.
# Salvando progresso após 75 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67424] Processando código 512499 com `analisar_texto_arg_linguistica`...
# [67424] Código 512499 processado com sucesso.
# [67425] Processando código 512484 com `analisar_texto_arg_linguistica`...
# [67425] Código 512484 processado com sucesso.
# [67426] Processando código 511829 com `analisar_texto_arg_linguistica`...
# [67426] Código 511829 processado com sucesso.
# [67427] Processando código 511789 com `analisar_texto_arg_linguistica`...
# [67427] Código 511789 processado com sucesso.
# [67428] Processando código 511775 com `analisar_texto_arg_linguistica`...
# [67428] Código 511775 processado com sucesso.
# Salvando progresso após 80 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67429] Processando código 511730 com `analisar_texto_arg_linguistica`...
# [67429] Código 511730 processado com sucesso.
# [67430] Processando código 511544 com `analisar_texto_arg_linguistica`...
# [67430] Código 511544 processado com sucesso.
# [67431] Processando código 511523 com `analisar_texto_arg_linguistica`...
# [67431] Código 511523 processado com sucesso.
# [67432] Processando código 511499 com `analisar_texto_arg_linguistica`...
# [67432] Código 511499 processado com sucesso.
# [67433] Processando código 511487 com `analisar_texto_arg_linguistica`...
# [67433] Código 511487 processado com sucesso.
# Salvando progresso após 85 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67434] Processando código 511473 com `analisar_texto_arg_linguistica`...
# [67434] Código 511473 processado com sucesso.
# [67435] Processando código 511471 com `analisar_texto_arg_linguistica`...
# [67435] Código 511471 processado com sucesso.
# [67436] Processando código 511432 com `analisar_texto_arg_linguistica`...
# [67436] Código 511432 processado com sucesso.
# [67437] Processando código 511421 com `analisar_texto_arg_linguistica`...
# [67437] Código 511421 processado com sucesso.
# [67438] Processando código 510744 com `analisar_texto_arg_linguistica`...
# [67438] Código 510744 processado com sucesso.
# Salvando progresso após 90 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67439] Processando código 510738 com `analisar_texto_arg_linguistica`...
# [67439] Código 510738 processado com sucesso.
# [67440] Processando código 510647 com `analisar_texto_arg_linguistica`...
# [67440] Código 510647 processado com sucesso.
# [67441] Processando código 511285 com `analisar_texto_arg_linguistica`...
# [67441] Código 511285 processado com sucesso.
# [67442] Processando código 511272 com `analisar_texto_arg_linguistica`...
# [67442] Código 511272 processado com sucesso.
# [67443] Processando código 511246 com `analisar_texto_arg_linguistica`...
# [67443] Código 511246 processado com sucesso.
# Salvando progresso após 95 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67444] Processando código 511231 com `analisar_texto_arg_linguistica`...
# [67444] Código 511231 processado com sucesso.
# [67445] Processando código 511215 com `analisar_texto_arg_linguistica`...
# [67445] Código 511215 processado com sucesso.
# [67446] Processando código 511158 com `analisar_texto_arg_linguistica`...
# [67446] Código 511158 processado com sucesso.
# [67447] Processando código 511143 com `analisar_texto_arg_linguistica`...
# [67447] Código 511143 processado com sucesso.
# [67448] Processando código 511064 com `analisar_texto_arg_linguistica`...
# [67448] Código 511064 processado com sucesso.
# Salvando progresso após 100 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67449] Processando código 512047 com `analisar_texto_arg_linguistica`...
# [67449] Código 512047 processado com sucesso.
# [67450] Processando código 512032 com `analisar_texto_arg_linguistica`...
# [67450] Código 512032 processado com sucesso.
# [67451] Processando código 512028 com `analisar_texto_arg_linguistica`...
# [67451] Código 512028 processado com sucesso.
# [67452] Processando código 511937 com `analisar_texto_arg_linguistica`...
# [67452] Código 511937 processado com sucesso.
# [67453] Processando código 512644 com `analisar_texto_arg_linguistica`...
# [67453] Código 512644 processado com sucesso.
# Salvando progresso após 105 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67454] Processando código 512534 com `analisar_texto_arg_linguistica`...
# [67454] Código 512534 processado com sucesso.
# [67455] Processando código 512530 com `analisar_texto_arg_linguistica`...
# [67455] Código 512530 processado com sucesso.
# [67456] Processando código 512519 com `analisar_texto_arg_linguistica`...
# [67456] Código 512519 processado com sucesso.
# [67457] Processando código 512450 com `analisar_texto_arg_linguistica`...
# [67457] Código 512450 processado com sucesso.
# [67458] Processando código 512382 com `analisar_texto_arg_linguistica`...
# [67458] Código 512382 processado com sucesso.
# Salvando progresso após 110 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67459] Processando código 512136 com `analisar_texto_arg_linguistica`...
# [67459] Código 512136 processado com sucesso.
# [67460] Processando código 512102 com `analisar_texto_arg_linguistica`...
# [67460] Código 512102 processado com sucesso.
# [67461] Processando código 511821 com `analisar_texto_arg_linguistica`...
# [67461] Código 511821 processado com sucesso.
# [67462] Processando código 511749 com `analisar_texto_arg_linguistica`...
# [67462] Código 511749 processado com sucesso.
# [67463] Processando código 511643 com `analisar_texto_arg_linguistica`...
# [67463] Código 511643 processado com sucesso.
# Salvando progresso após 115 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67464] Processando código 511626 com `analisar_texto_arg_linguistica`...
# [67464] Código 511626 processado com sucesso.
# [67465] Processando código 511581 com `analisar_texto_arg_linguistica`...
# [67465] Código 511581 processado com sucesso.
# [67466] Processando código 511553 com `analisar_texto_arg_linguistica`...
# [67466] Código 511553 processado com sucesso.
# [67467] Processando código 511551 com `analisar_texto_arg_linguistica`...
# [67467] Código 511551 processado com sucesso.
# [67468] Processando código 511541 com `analisar_texto_arg_linguistica`...
# [67468] Código 511541 processado com sucesso.
# Salvando progresso após 120 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67469] Processando código 511520 com `analisar_texto_arg_linguistica`...
# [67469] Código 511520 processado com sucesso.
# [67470] Processando código 511510 com `analisar_texto_arg_linguistica`...
# [67470] Código 511510 processado com sucesso.
# [67471] Processando código 511496 com `analisar_texto_arg_linguistica`...
# [67471] Código 511496 processado com sucesso.
# [67472] Processando código 511486 com `analisar_texto_arg_linguistica`...
# [67472] Código 511486 processado com sucesso.
# [67473] Processando código 511467 com `analisar_texto_arg_linguistica`...
# [67473] Código 511467 processado com sucesso.
# Salvando progresso após 125 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67474] Processando código 511459 com `analisar_texto_arg_linguistica`...
# [67474] Código 511459 processado com sucesso.
# [67475] Processando código 511425 com `analisar_texto_arg_linguistica`...
# [67475] Código 511425 processado com sucesso.
# [67476] Processando código 511423 com `analisar_texto_arg_linguistica`...
# [67476] Código 511423 processado com sucesso.
# [67477] Processando código 511419 com `analisar_texto_arg_linguistica`...
# [67477] Código 511419 processado com sucesso.
# [67478] Processando código 511413 com `analisar_texto_arg_linguistica`...
# [67478] Código 511413 processado com sucesso.
# Salvando progresso após 130 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67479] Processando código 510700 com `analisar_texto_arg_linguistica`...
# [67479] Código 510700 processado com sucesso.
# [67480] Processando código 510694 com `analisar_texto_arg_linguistica`...
# [67480] Código 510694 processado com sucesso.
# [67481] Processando código 510668 com `analisar_texto_arg_linguistica`...
# [67481] Código 510668 processado com sucesso.
# [67482] Processando código 510655 com `analisar_texto_arg_linguistica`...
# [67482] Código 510655 processado com sucesso.
# [67483] Processando código 511355 com `analisar_texto_arg_linguistica`...
# [67483] Código 511355 processado com sucesso.
# Salvando progresso após 135 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67484] Processando código 511326 com `analisar_texto_arg_linguistica`...
# [67484] Código 511326 processado com sucesso.
# [67485] Processando código 511264 com `analisar_texto_arg_linguistica`...
# [67485] Código 511264 processado com sucesso.
# [67486] Processando código 511073 com `analisar_texto_arg_linguistica`...
# [67486] Código 511073 processado com sucesso.
# [67487] Processando código 511942 com `analisar_texto_arg_linguistica`...
# [67487] Código 511942 processado com sucesso.
# [67488] Processando código 512518 com `analisar_texto_arg_linguistica`...
# [67488] Código 512518 processado com sucesso.
# Salvando progresso após 140 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67489] Processando código 512348 com `analisar_texto_arg_linguistica`...
# [67489] Código 512348 processado com sucesso.
# [67490] Processando código 512184 com `analisar_texto_arg_linguistica`...
# [67490] Código 512184 processado com sucesso.
# [67491] Processando código 511846 com `analisar_texto_arg_linguistica`...
# [67491] Código 511846 processado com sucesso.
# [67492] Processando código 510791 com `analisar_texto_arg_linguistica`...
# [67492] Código 510791 processado com sucesso.
# [67493] Processando código 510787 com `analisar_texto_arg_linguistica`...
# [67493] Código 510787 processado com sucesso.
# Salvando progresso após 145 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67494] Processando código 510725 com `analisar_texto_arg_linguistica`...
# [67494] Código 510725 processado com sucesso.
# [67495] Processando código 511049 com `analisar_texto_arg_linguistica`...
# [67495] Código 511049 processado com sucesso.
# [67496] Processando código 510987 com `analisar_texto_arg_linguistica`...
# [67496] Código 510987 processado com sucesso.
# [67497] Processando código 511948 com `analisar_texto_arg_linguistica`...
# [67497] Código 511948 processado com sucesso.
# [67498] Processando código 512648 com `analisar_texto_arg_linguistica`...
# [67498] Código 512648 processado com sucesso.
# Salvando progresso após 150 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67499] Processando código 512268 com `analisar_texto_arg_linguistica`...
# [67499] Código 512268 processado com sucesso.
# [67500] Processando código 512233 com `analisar_texto_arg_linguistica`...
# [67500] Código 512233 processado com sucesso.
# [67501] Processando código 512212 com `analisar_texto_arg_linguistica`...
# [67501] Código 512212 processado com sucesso.
# [67502] Processando código 510783 com `analisar_texto_arg_linguistica`...
# [67502] Código 510783 processado com sucesso.
# [67503] Processando código 510781 com `analisar_texto_arg_linguistica`...
# [67503] Código 510781 processado com sucesso.
# Salvando progresso após 155 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67504] Processando código 510778 com `analisar_texto_arg_linguistica`...
# [67504] Código 510778 processado com sucesso.
# [67505] Processando código 510711 com `analisar_texto_arg_linguistica`...
# [67505] Código 510711 processado com sucesso.
# [67506] Processando código 512634 com `analisar_texto_arg_linguistica`...
# [67506] Código 512634 processado com sucesso.
# [67507] Processando código 511944 com `analisar_texto_arg_linguistica`...
# [67507] Código 511944 processado com sucesso.
# [67508] Processando código 512510 com `analisar_texto_arg_linguistica`...
# [67508] Código 512510 processado com sucesso.
# Salvando progresso após 160 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67509] Processando código 512215 com `analisar_texto_arg_linguistica`...
# [67509] Código 512215 processado com sucesso.
# [67510] Processando código 510751 com `analisar_texto_arg_linguistica`...
# [67510] Código 510751 processado com sucesso.
# [67511] Processando código 510732 com `analisar_texto_arg_linguistica`...
# [67511] Código 510732 processado com sucesso.
# [67512] Processando código 510730 com `analisar_texto_arg_linguistica`...
# [67512] Código 510730 processado com sucesso.
# [67513] Processando código 510624 com `analisar_texto_arg_linguistica`...
# [67513] Código 510624 processado com sucesso.
# Salvando progresso após 165 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67514] Processando código 511123 com `analisar_texto_arg_linguistica`...
# [67514] Código 511123 processado com sucesso.
# [67515] Processando código 511374 com `analisar_texto_arg_linguistica`...
# [67515] Código 511374 processado com sucesso.
# [67516] Processando código 511350 com `analisar_texto_arg_linguistica`...
# [67516] Código 511350 processado com sucesso.
# [67517] Processando código 511316 com `analisar_texto_arg_linguistica`...
# [67517] Código 511316 processado com sucesso.
# [67518] Processando código 511259 com `analisar_texto_arg_linguistica`...
# [67518] Código 511259 processado com sucesso.
# Salvando progresso após 170 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67519] Processando código 511242 com `analisar_texto_arg_linguistica`...
# [67519] Código 511242 processado com sucesso.
# [67520] Processando código 510943 com `analisar_texto_arg_linguistica`...
# [67520] Código 510943 processado com sucesso.
# [67521] Processando código 510910 com `analisar_texto_arg_linguistica`...
# [67521] Código 510910 processado com sucesso.
# [67522] Processando código 510897 com `analisar_texto_arg_linguistica`...
# [67522] Código 510897 processado com sucesso.
# [67523] Processando código 510891 com `analisar_texto_arg_linguistica`...
# [67523] Código 510891 processado com sucesso.
# Salvando progresso após 175 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67524] Processando código 512453 com `analisar_texto_arg_linguistica`...
# [67524] Código 512453 processado com sucesso.
# [67525] Processando código 512427 com `analisar_texto_arg_linguistica`...
# [67525] Código 512427 processado com sucesso.
# [67526] Processando código 512388 com `analisar_texto_arg_linguistica`...
# [67526] Código 512388 processado com sucesso.
# [67527] Processando código 512366 com `analisar_texto_arg_linguistica`...
# [67527] Código 512366 processado com sucesso.
# [67528] Processando código 512354 com `analisar_texto_arg_linguistica`...
# [67528] Código 512354 processado com sucesso.
# Salvando progresso após 180 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67529] Processando código 512230 com `analisar_texto_arg_linguistica`...
# [67529] Código 512230 processado com sucesso.
# [67530] Processando código 511710 com `analisar_texto_arg_linguistica`...
# [67530] Código 511710 processado com sucesso.
# [67531] Processando código 511682 com `analisar_texto_arg_linguistica`...
# [67531] Código 511682 processado com sucesso.
# [67532] Processando código 511593 com `analisar_texto_arg_linguistica`...
# [67532] Código 511593 processado com sucesso.
# [67533] Processando código 510761 com `analisar_texto_arg_linguistica`...
# [67533] Código 510761 processado com sucesso.
# Salvando progresso após 185 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67534] Processando código 510615 com `analisar_texto_arg_linguistica`...
# [67534] Código 510615 processado com sucesso.
# [67535] Processando código 511085 com `analisar_texto_arg_linguistica`...
# [67535] Código 511085 processado com sucesso.
# [67536] Processando código 511386 com `analisar_texto_arg_linguistica`...
# [67536] Código 511386 processado com sucesso.
# [67537] Processando código 511035 com `analisar_texto_arg_linguistica`...
# [67537] Código 511035 processado com sucesso.
# [67538] Processando código 510961 com `analisar_texto_arg_linguistica`...
# [67538] Código 510961 processado com sucesso.
# Salvando progresso após 190 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67539] Processando código 510913 com `analisar_texto_arg_linguistica`...
# [67539] Código 510913 processado com sucesso.
# [67540] Processando código 510883 com `analisar_texto_arg_linguistica`...
# [67540] Código 510883 processado com sucesso.
# [67541] Processando código 511991 com `analisar_texto_arg_linguistica`...
# [67541] Código 511991 processado com sucesso.
# [67542] Processando código 512649 com `analisar_texto_arg_linguistica`...
# [67542] Código 512649 processado com sucesso.
# [67543] Processando código 512345 com `analisar_texto_arg_linguistica`...
# [67543] Código 512345 processado com sucesso.
# Salvando progresso após 195 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67544] Processando código 512256 com `analisar_texto_arg_linguistica`...
# [67544] Código 512256 processado com sucesso.
# [67545] Processando código 512235 com `analisar_texto_arg_linguistica`...
# [67545] Código 512235 processado com sucesso.
# [67546] Processando código 513093 com `analisar_texto_arg_linguistica`...
# [67546] Código 513093 processado com sucesso.
# [67547] Processando código 494843 com `analisar_texto_arg_linguistica`...
# [67547] Código 494843 processado com sucesso.
# [67548] Processando código 495500 com `analisar_texto_arg_linguistica`...
# [67548] Código 495500 processado com sucesso.
# Salvando progresso após 200 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67549] Processando código 497088 com `analisar_texto_arg_linguistica`...
# [67549] Código 497088 processado com sucesso.
# [67550] Processando código 496885 com `analisar_texto_arg_linguistica`...
# [67550] Código 496885 processado com sucesso.
# [67551] Processando código 496675 com `analisar_texto_arg_linguistica`...
# [67551] Código 496675 processado com sucesso.
# [67552] Processando código 497338 com `analisar_texto_arg_linguistica`...
# [67552] Código 497338 processado com sucesso.
# [67553] Processando código 498597 com `analisar_texto_arg_linguistica`...
# [67553] Código 498597 processado com sucesso.
# Salvando progresso após 205 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67554] Processando código 498320 com `analisar_texto_arg_linguistica`...
# [67554] Código 498320 processado com sucesso.
# [67555] Processando código 498310 com `analisar_texto_arg_linguistica`...
# [67555] Código 498310 processado com sucesso.
# [67556] Processando código 498903 com `analisar_texto_arg_linguistica`...
# [67556] Código 498903 processado com sucesso.
# [67557] Processando código 500722 com `analisar_texto_arg_linguistica`...
# [67557] Código 500722 processado com sucesso.
# [67558] Processando código 500109 com `analisar_texto_arg_linguistica`...
# [67558] Código 500109 processado com sucesso.
# Salvando progresso após 210 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67559] Processando código 499803 com `analisar_texto_arg_linguistica`...
# [67559] Código 499803 processado com sucesso.
# [67560] Processando código 500615 com `analisar_texto_arg_linguistica`...
# [67560] Código 500615 processado com sucesso.
# [67561] Processando código 501439 com `analisar_texto_arg_linguistica`...
# [67561] Código 501439 processado com sucesso.
# [67562] Processando código 502488 com `analisar_texto_arg_linguistica`...
# [67562] Código 502488 processado com sucesso.
# [67563] Processando código 502472 com `analisar_texto_arg_linguistica`...
# [67563] Código 502472 processado com sucesso.
# Salvando progresso após 215 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67564] Processando código 502590 com `analisar_texto_arg_linguistica`...
# [67564] Código 502590 processado com sucesso.
# [67565] Processando código 502566 com `analisar_texto_arg_linguistica`...
# [67565] Código 502566 processado com sucesso.
# [67566] Processando código 502411 com `analisar_texto_arg_linguistica`...
# [67566] Código 502411 processado com sucesso.
# [67567] Processando código 502406 com `analisar_texto_arg_linguistica`...
# [67567] Código 502406 processado com sucesso.
# [67568] Processando código 501881 com `analisar_texto_arg_linguistica`...
# [67568] Código 501881 processado com sucesso.
# Salvando progresso após 220 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67569] Processando código 503358 com `analisar_texto_arg_linguistica`...
# [67569] Código 503358 processado com sucesso.
# [67570] Processando código 503159 com `analisar_texto_arg_linguistica`...
# [67570] Código 503159 processado com sucesso.
# [67571] Processando código 503133 com `analisar_texto_arg_linguistica`...
# [67571] Código 503133 processado com sucesso.
# [67572] Processando código 503111 com `analisar_texto_arg_linguistica`...
# [67572] Código 503111 processado com sucesso.
# [67573] Processando código 503097 com `analisar_texto_arg_linguistica`...
# [67573] Código 503097 processado com sucesso.
# Salvando progresso após 225 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67574] Processando código 504700 com `analisar_texto_arg_linguistica`...
# [67574] Código 504700 processado com sucesso.
# [67575] Processando código 504678 com `analisar_texto_arg_linguistica`...
# [67575] Código 504678 processado com sucesso.
# [67576] Processando código 505290 com `analisar_texto_arg_linguistica`...
# [67576] Código 505290 processado com sucesso.
# [67577] Processando código 507499 com `analisar_texto_arg_linguistica`...
# [67577] Código 507499 processado com sucesso.
# [67578] Processando código 507486 com `analisar_texto_arg_linguistica`...
# [67578] Código 507486 processado com sucesso.
# Salvando progresso após 230 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67579] Processando código 506084 com `analisar_texto_arg_linguistica`...
# [67579] Código 506084 processado com sucesso.
# [67580] Processando código 506077 com `analisar_texto_arg_linguistica`...
# [67580] Código 506077 processado com sucesso.
# [67581] Processando código 506075 com `analisar_texto_arg_linguistica`...
# [67581] Código 506075 processado com sucesso.
# [67582] Processando código 506914 com `analisar_texto_arg_linguistica`...
# [67582] Código 506914 processado com sucesso.
# [67583] Processando código 506892 com `analisar_texto_arg_linguistica`...
# [67583] Código 506892 processado com sucesso.
# Salvando progresso após 235 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67584] Processando código 507587 com `analisar_texto_arg_linguistica`...
# [67584] Código 507587 processado com sucesso.
# [67585] Processando código 507568 com `analisar_texto_arg_linguistica`...
# [67585] Código 507568 processado com sucesso.
# [67586] Processando código 507562 com `analisar_texto_arg_linguistica`...
# [67586] Código 507562 processado com sucesso.
# [67587] Processando código 508380 com `analisar_texto_arg_linguistica`...
# [67587] Código 508380 processado com sucesso.
# [67588] Processando código 508363 com `analisar_texto_arg_linguistica`...
# [67588] Código 508363 processado com sucesso.
# Salvando progresso após 240 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67589] Processando código 509810 com `analisar_texto_arg_linguistica`...
# [67589] Código 509810 processado com sucesso.
# [67590] Processando código 509508 com `analisar_texto_arg_linguistica`...
# [67590] Código 509508 processado com sucesso.
# [67591] Processando código 509386 com `analisar_texto_arg_linguistica`...
# [67591] Código 509386 processado com sucesso.
# [67592] Processando código 509871 com `analisar_texto_arg_linguistica`...
# [67592] Código 509871 processado com sucesso.
# [67593] Processando código 511633 com `analisar_texto_arg_linguistica`...
# [67593] Código 511633 processado com sucesso.
# Salvando progresso após 245 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67594] Processando código 511612 com `analisar_texto_arg_linguistica`...
# [67594] Código 511612 processado com sucesso.
# [67595] Processando código 511597 com `analisar_texto_arg_linguistica`...
# [67595] Código 511597 processado com sucesso.
# [67596] Processando código 511579 com `analisar_texto_arg_linguistica`...
# [67596] Código 511579 processado com sucesso.
# [67597] Processando código 511571 com `analisar_texto_arg_linguistica`...
# [67597] Código 511571 processado com sucesso.
# [67598] Processando código 511561 com `analisar_texto_arg_linguistica`...
# [67598] Código 511561 processado com sucesso.
# Salvando progresso após 250 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67599] Processando código 511557 com `analisar_texto_arg_linguistica`...
# [67599] Código 511557 processado com sucesso.
# [67600] Processando código 511434 com `analisar_texto_arg_linguistica`...
# [67600] Código 511434 processado com sucesso.
# [67601] Processando código 511216 com `analisar_texto_arg_linguistica`...
# [67601] Código 511216 processado com sucesso.
# [67602] Processando código 511197 com `analisar_texto_arg_linguistica`...
# [67602] Código 511197 processado com sucesso.
# [67603] Processando código 511254 com `analisar_texto_arg_linguistica`...
# [67603] Código 511254 processado com sucesso.
# Salvando progresso após 255 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67604] Processando código 511983 com `analisar_texto_arg_linguistica`...
# [67604] Código 511983 processado com sucesso.
# [67605] Processando código 511975 com `analisar_texto_arg_linguistica`...
# [67605] Código 511975 processado com sucesso.
# [67606] Processando código 512425 com `analisar_texto_arg_linguistica`...
# [67606] Código 512425 processado com sucesso.
# [67607] Processando código 512384 com `analisar_texto_arg_linguistica`...
# [67607] Código 512384 processado com sucesso.
# [67608] Processando código 512134 com `analisar_texto_arg_linguistica`...
# [67608] Código 512134 processado com sucesso.
# Salvando progresso após 260 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67609] Processando código 511803 com `analisar_texto_arg_linguistica`...
# [67609] Código 511803 processado com sucesso.
# [67610] Processando código 511778 com `analisar_texto_arg_linguistica`...
# [67610] Código 511778 processado com sucesso.
# [67611] Processando código 511716 com `analisar_texto_arg_linguistica`...
# [67611] Código 511716 processado com sucesso.
# [67612] Processando código 511671 com `analisar_texto_arg_linguistica`...
# [67612] Código 511671 processado com sucesso.
# [67613] Processando código 511620 com `analisar_texto_arg_linguistica`...
# [67613] Código 511620 processado com sucesso.
# Salvando progresso após 265 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67614] Processando código 511548 com `analisar_texto_arg_linguistica`...
# [67614] Código 511548 processado com sucesso.
# [67615] Processando código 511527 com `analisar_texto_arg_linguistica`...
# [67615] Código 511527 processado com sucesso.
# [67616] Processando código 511503 com `analisar_texto_arg_linguistica`...
# [67616] Código 511503 processado com sucesso.
# [67617] Processando código 511438 com `analisar_texto_arg_linguistica`...
# [67617] Código 511438 processado com sucesso.
# [67618] Processando código 510749 com `analisar_texto_arg_linguistica`...
# [67618] Código 510749 processado com sucesso.
# Salvando progresso após 270 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67619] Processando código 510688 com `analisar_texto_arg_linguistica`...
# [67619] Código 510688 processado com sucesso.
# [67620] Processando código 510678 com `analisar_texto_arg_linguistica`...
# [67620] Código 510678 processado com sucesso.
# [67621] Processando código 510649 com `analisar_texto_arg_linguistica`...
# [67621] Código 510649 processado com sucesso.
# [67622] Processando código 511310 com `analisar_texto_arg_linguistica`...
# [67622] Código 511310 processado com sucesso.
# [67623] Processando código 511277 com `analisar_texto_arg_linguistica`...
# [67623] Código 511277 processado com sucesso.
# Salvando progresso após 275 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67624] Processando código 511222 com `analisar_texto_arg_linguistica`...
# [67624] Código 511222 processado com sucesso.
# [67625] Processando código 511182 com `analisar_texto_arg_linguistica`...
# [67625] Código 511182 processado com sucesso.
# [67626] Processando código 511258 com `analisar_texto_arg_linguistica`...
# [67626] Código 511258 processado com sucesso.
# [67627] Processando código 510930 com `analisar_texto_arg_linguistica`...
# [67627] Código 510930 processado com sucesso.
# [67628] Processando código 512035 com `analisar_texto_arg_linguistica`...
# [67628] Código 512035 processado com sucesso.
# Salvando progresso após 280 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67629] Processando código 511938 com `analisar_texto_arg_linguistica`...
# [67629] Código 511938 processado com sucesso.
# [67630] Processando código 512665 com `analisar_texto_arg_linguistica`...
# [67630] Código 512665 processado com sucesso.
# [67631] Processando código 512653 com `analisar_texto_arg_linguistica`...
# [67631] Código 512653 processado com sucesso.
# [67632] Processando código 512535 com `analisar_texto_arg_linguistica`...
# [67632] Código 512535 processado com sucesso.
# [67633] Processando código 512204 com `analisar_texto_arg_linguistica`...
# [67633] Código 512204 processado com sucesso.
# Salvando progresso após 285 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67634] Processando código 512189 com `analisar_texto_arg_linguistica`...
# [67634] Código 512189 processado com sucesso.
# [67635] Processando código 512178 com `analisar_texto_arg_linguistica`...
# [67635] Código 512178 processado com sucesso.
# [67636] Processando código 511354 com `analisar_texto_arg_linguistica`...
# [67636] Código 511354 processado com sucesso.
# [67637] Processando código 511325 com `analisar_texto_arg_linguistica`...
# [67637] Código 511325 processado com sucesso.
# [67638] Processando código 511273 com `analisar_texto_arg_linguistica`...
# [67638] Código 511273 processado com sucesso.
# Salvando progresso após 290 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67639] Processando código 511149 com `analisar_texto_arg_linguistica`...
# [67639] Código 511149 processado com sucesso.
# [67640] Processando código 512386 com `analisar_texto_arg_linguistica`...
# [67640] Código 512386 processado com sucesso.
# [67641] Processando código 511854 com `analisar_texto_arg_linguistica`...
# [67641] Código 511854 processado com sucesso.
# [67642] Processando código 511815 com `analisar_texto_arg_linguistica`...
# [67642] Código 511815 processado com sucesso.
# [67643] Processando código 511645 com `analisar_texto_arg_linguistica`...
# [67643] Código 511645 processado com sucesso.
# Salvando progresso após 295 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67644] Processando código 511629 com `analisar_texto_arg_linguistica`...
# [67644] Código 511629 processado com sucesso.
# [67645] Processando código 511623 com `analisar_texto_arg_linguistica`...
# [67645] Código 511623 processado com sucesso.
# [67646] Processando código 511507 com `analisar_texto_arg_linguistica`...
# [67646] Código 511507 processado com sucesso.
# [67647] Processando código 511451 com `analisar_texto_arg_linguistica`...
# [67647] Código 511451 processado com sucesso.
# [67648] Processando código 511399 com `analisar_texto_arg_linguistica`...
# [67648] Código 511399 processado com sucesso.
# Salvando progresso após 300 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67649] Processando código 510790 com `analisar_texto_arg_linguistica`...
# [67649] Código 510790 processado com sucesso.
# [67650] Processando código 510762 com `analisar_texto_arg_linguistica`...
# [67650] Código 510762 processado com sucesso.
# [67651] Processando código 510759 com `analisar_texto_arg_linguistica`...
# [67651] Código 510759 processado com sucesso.
# [67652] Processando código 510754 com `analisar_texto_arg_linguistica`...
# [67652] Código 510754 processado com sucesso.
# [67653] Processando código 510717 com `analisar_texto_arg_linguistica`...
# [67653] Código 510717 processado com sucesso.
# Salvando progresso após 305 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67654] Processando código 510654 com `analisar_texto_arg_linguistica`...
# [67654] Código 510654 processado com sucesso.
# [67655] Processando código 510618 com `analisar_texto_arg_linguistica`...
# [67655] Código 510618 processado com sucesso.
# [67656] Processando código 511282 com `analisar_texto_arg_linguistica`...
# [67656] Código 511282 processado com sucesso.
# [67657] Processando código 511263 com `analisar_texto_arg_linguistica`...
# [67657] Código 511263 processado com sucesso.
# [67658] Processando código 511243 com `analisar_texto_arg_linguistica`...
# [67658] Código 511243 processado com sucesso.
# Salvando progresso após 310 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67659] Processando código 511227 com `analisar_texto_arg_linguistica`...
# [67659] Código 511227 processado com sucesso.
# [67660] Processando código 511168 com `analisar_texto_arg_linguistica`...
# [67660] Código 511168 processado com sucesso.
# [67661] Processando código 511092 com `analisar_texto_arg_linguistica`...
# [67661] Código 511092 processado com sucesso.
# [67662] Processando código 511008 com `analisar_texto_arg_linguistica`...
# [67662] Código 511008 processado com sucesso.
# [67663] Processando código 511395 com `analisar_texto_arg_linguistica`...
# [67663] Código 511395 processado com sucesso.
# Salvando progresso após 315 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67664] Processando código 511392 com `analisar_texto_arg_linguistica`...
# [67664] Código 511392 processado com sucesso.
# [67665] Processando código 511381 com `analisar_texto_arg_linguistica`...
# [67665] Código 511381 processado com sucesso.
# [67666] Processando código 511376 com `analisar_texto_arg_linguistica`...
# [67666] Código 511376 processado com sucesso.
# [67667] Processando código 511353 com `analisar_texto_arg_linguistica`...
# [67667] Código 511353 processado com sucesso.
# [67668] Processando código 511321 com `analisar_texto_arg_linguistica`...
# [67668] Código 511321 processado com sucesso.
# Salvando progresso após 320 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67669] Processando código 511179 com `analisar_texto_arg_linguistica`...
# [67669] Código 511179 processado com sucesso.
# [67670] Processando código 511161 com `analisar_texto_arg_linguistica`...
# [67670] Código 511161 processado com sucesso.
# [67671] Processando código 511146 com `analisar_texto_arg_linguistica`...
# [67671] Código 511146 processado com sucesso.
# [67672] Processando código 511127 com `analisar_texto_arg_linguistica`...
# [67672] Código 511127 processado com sucesso.
# [67673] Processando código 511107 com `analisar_texto_arg_linguistica`...
# [67673] Código 511107 processado com sucesso.
# Salvando progresso após 325 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67674] Processando código 511084 com `analisar_texto_arg_linguistica`...
# [67674] Código 511084 processado com sucesso.
# [67675] Processando código 511056 com `analisar_texto_arg_linguistica`...
# [67675] Código 511056 processado com sucesso.
# [67676] Processando código 511045 com `analisar_texto_arg_linguistica`...
# [67676] Código 511045 processado com sucesso.
# [67677] Processando código 510955 com `analisar_texto_arg_linguistica`...
# [67677] Código 510955 processado com sucesso.
# [67678] Processando código 510969 com `analisar_texto_arg_linguistica`...
# [67678] Código 510969 processado com sucesso.
# Salvando progresso após 330 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67679] Processando código 510952 com `analisar_texto_arg_linguistica`...
# [67679] Código 510952 processado com sucesso.
# [67680] Processando código 510874 com `analisar_texto_arg_linguistica`...
# [67680] Código 510874 processado com sucesso.
# [67681] Processando código 510448 com `analisar_texto_arg_linguistica`...
# [67681] Código 510448 processado com sucesso.
# [67682] Processando código 511985 com `analisar_texto_arg_linguistica`...
# [67682] Código 511985 processado com sucesso.
# [67683] Processando código 511958 com `analisar_texto_arg_linguistica`...
# [67683] Código 511958 processado com sucesso.
# Salvando progresso após 335 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [67684] Processando código 511951 com `analisar_texto_arg_linguistica`...
# ...
# [69408] Código 511144 processado com sucesso.
# Salvando progresso após 2060 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69409] Processando código 511940 com `analisar_texto_arg_linguistica`...
# [69409] Código 511940 processado com sucesso.
# [69410] Processando código 512156 com `analisar_texto_arg_linguistica`...
# [69410] Código 512156 processado com sucesso.
# [69411] Processando código 511270 com `analisar_texto_arg_linguistica`...
# [69411] Código 511270 processado com sucesso.
# [69412] Processando código 511164 com `analisar_texto_arg_linguistica`...
# [69412] Código 511164 processado com sucesso.
# [69413] Processando código 511341 com `analisar_texto_arg_linguistica`...
# [69413] Código 511341 processado com sucesso.
# Salvando progresso após 2065 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69414] Processando código 511297 com `analisar_texto_arg_linguistica`...
# [69414] Código 511297 processado com sucesso.
# [69415] Processando código 511089 com `analisar_texto_arg_linguistica`...
# [69415] Código 511089 processado com sucesso.
# [69416] Processando código 511071 com `analisar_texto_arg_linguistica`...
# [69416] Código 511071 processado com sucesso.
# [69417] Processando código 511922 com `analisar_texto_arg_linguistica`...
# [69417] Código 511922 processado com sucesso.
# [69418] Processando código 512172 com `analisar_texto_arg_linguistica`...
# [69418] Código 512172 processado com sucesso.
# Salvando progresso após 2070 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69419] Processando código 511225 com `analisar_texto_arg_linguistica`...
# [69419] Código 511225 processado com sucesso.
# [69420] Processando código 510978 com `analisar_texto_arg_linguistica`...
# [69420] Código 510978 processado com sucesso.
# [69421] Processando código 510923 com `analisar_texto_arg_linguistica`...
# [69421] Código 510923 processado com sucesso.
# [69422] Processando código 512046 com `analisar_texto_arg_linguistica`...
# [69422] Código 512046 processado com sucesso.
# [69423] Processando código 511924 com `analisar_texto_arg_linguistica`...
# [69423] Código 511924 processado com sucesso.
# Salvando progresso após 2075 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69424] Processando código 512640 com `analisar_texto_arg_linguistica`...
# [69424] Código 512640 processado com sucesso.
# [69425] Processando código 512493 com `analisar_texto_arg_linguistica`...
# [69425] Código 512493 processado com sucesso.
# [69426] Processando código 512487 com `analisar_texto_arg_linguistica`...
# [69426] Código 512487 processado com sucesso.
# [69427] Processando código 512222 com `analisar_texto_arg_linguistica`...
# [69427] Código 512222 processado com sucesso.
# [69428] Processando código 511807 com `analisar_texto_arg_linguistica`...
# [69428] Código 511807 processado com sucesso.
# Salvando progresso após 2080 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69429] Processando código 511781 com `analisar_texto_arg_linguistica`...
# [69429] Código 511781 processado com sucesso.
# [69430] Processando código 511728 com `analisar_texto_arg_linguistica`...
# [69430] Código 511728 processado com sucesso.
# [69431] Processando código 511659 com `analisar_texto_arg_linguistica`...
# [69431] Código 511659 processado com sucesso.
# [69432] Processando código 511574 com `analisar_texto_arg_linguistica`...
# [69432] Código 511574 processado com sucesso.
# [69433] Processando código 510785 com `analisar_texto_arg_linguistica`...
# [69433] Código 510785 processado com sucesso.
# Salvando progresso após 2085 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69434] Processando código 510775 com `analisar_texto_arg_linguistica`...
# [69434] Código 510775 processado com sucesso.
# [69435] Processando código 510611 com `analisar_texto_arg_linguistica`...
# [69435] Código 510611 processado com sucesso.
# [69436] Processando código 511099 com `analisar_texto_arg_linguistica`...
# [69436] Código 511099 processado com sucesso.
# [69437] Processando código 511009 com `analisar_texto_arg_linguistica`...
# [69437] Código 511009 processado com sucesso.
# [69438] Processando código 511382 com `analisar_texto_arg_linguistica`...
# [69438] Código 511382 processado com sucesso.
# Salvando progresso após 2090 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69439] Processando código 510974 com `analisar_texto_arg_linguistica`...
# [69439] Código 510974 processado com sucesso.
# [69440] Processando código 510856 com `analisar_texto_arg_linguistica`...
# [69440] Código 510856 processado com sucesso.
# [69441] Processando código 510465 com `analisar_texto_arg_linguistica`...
# [69441] Código 510465 processado com sucesso.
# [69442] Processando código 512647 com `analisar_texto_arg_linguistica`...
# [69442] Código 512647 processado com sucesso.
# [69443] Processando código 512536 com `analisar_texto_arg_linguistica`...
# [69443] Código 512536 processado com sucesso.
# Salvando progresso após 2095 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69444] Processando código 512488 com `analisar_texto_arg_linguistica`...
# [69444] Código 512488 processado com sucesso.
# [69445] Processando código 512365 com `analisar_texto_arg_linguistica`...
# [69445] Código 512365 processado com sucesso.
# [69446] Processando código 512295 com `analisar_texto_arg_linguistica`...
# [69446] Código 512295 processado com sucesso.
# [69447] Processando código 512277 com `analisar_texto_arg_linguistica`...
# [69447] Código 512277 processado com sucesso.
# [69448] Processando código 512275 com `analisar_texto_arg_linguistica`...
# [69448] Código 512275 processado com sucesso.
# Salvando progresso após 2100 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69449] Processando código 512209 com `analisar_texto_arg_linguistica`...
# [69449] Código 512209 processado com sucesso.
# [69450] Processando código 513091 com `analisar_texto_arg_linguistica`...
# [69450] Código 513091 processado com sucesso.
# [69451] Processando código 511837 com `analisar_texto_arg_linguistica`...
# [69451] Código 511837 processado com sucesso.
# [69452] Processando código 511768 com `analisar_texto_arg_linguistica`...
# [69452] Código 511768 processado com sucesso.
# [69453] Processando código 511745 com `analisar_texto_arg_linguistica`...
# [69453] Código 511745 processado com sucesso.
# Salvando progresso após 2105 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69454] Processando código 511724 com `analisar_texto_arg_linguistica`...
# [69454] Código 511724 processado com sucesso.
# [69455] Processando código 511190 com `analisar_texto_arg_linguistica`...
# [69455] Código 511190 processado com sucesso.
# [69456] Processando código 511117 com `analisar_texto_arg_linguistica`...
# [69456] Código 511117 processado com sucesso.
# [69457] Processando código 511186 com `analisar_texto_arg_linguistica`...
# [69457] Código 511186 processado com sucesso.
# [69458] Processando código 510972 com `analisar_texto_arg_linguistica`...
# [69458] Código 510972 processado com sucesso.
# Salvando progresso após 2110 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69459] Processando código 510932 com `analisar_texto_arg_linguistica`...
# [69459] Código 510932 processado com sucesso.
# [69460] Processando código 512036 com `analisar_texto_arg_linguistica`...
# [69460] Código 512036 processado com sucesso.
# [69461] Processando código 511934 com `analisar_texto_arg_linguistica`...
# [69461] Código 511934 processado com sucesso.
# [69462] Processando código 512532 com `analisar_texto_arg_linguistica`...
# [69462] Código 512532 processado com sucesso.
# [69463] Processando código 512377 com `analisar_texto_arg_linguistica`...
# [69463] Código 512377 processado com sucesso.
# Salvando progresso após 2115 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69464] Processando código 512360 com `analisar_texto_arg_linguistica`...
# [69464] Código 512360 processado com sucesso.
# [69465] Processando código 512246 com `analisar_texto_arg_linguistica`...
# [69465] Código 512246 processado com sucesso.
# [69466] Processando código 512224 com `analisar_texto_arg_linguistica`...
# [69466] Código 512224 processado com sucesso.
# [69467] Processando código 512202 com `analisar_texto_arg_linguistica`...
# [69467] Código 512202 processado com sucesso.
# [69468] Processando código 512176 com `analisar_texto_arg_linguistica`...
# [69468] Código 512176 processado com sucesso.
# Salvando progresso após 2120 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69469] Processando código 511409 com `analisar_texto_arg_linguistica`...
# [69469] Código 511409 processado com sucesso.
# [69470] Processando código 511401 com `analisar_texto_arg_linguistica`...
# [69470] Código 511401 processado com sucesso.
# [69471] Processando código 510726 com `analisar_texto_arg_linguistica`...
# [69471] Código 510726 processado com sucesso.
# [69472] Processando código 511346 com `analisar_texto_arg_linguistica`...
# [69472] Código 511346 processado com sucesso.
# [69473] Processando código 511322 com `analisar_texto_arg_linguistica`...
# [69473] Código 511322 processado com sucesso.
# Salvando progresso após 2125 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69474] Processando código 511308 com `analisar_texto_arg_linguistica`...
# [69474] Código 511308 processado com sucesso.
# [69475] Processando código 511185 com `analisar_texto_arg_linguistica`...
# [69475] Código 511185 processado com sucesso.
# [69476] Processando código 511368 com `analisar_texto_arg_linguistica`...
# [69476] Código 511368 processado com sucesso.
# [69477] Processando código 511342 com `analisar_texto_arg_linguistica`...
# [69477] Código 511342 processado com sucesso.
# [69478] Processando código 511324 com `analisar_texto_arg_linguistica`...
# [69478] Código 511324 processado com sucesso.
# Salvando progresso após 2130 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69479] Processando código 511171 com `analisar_texto_arg_linguistica`...
# [69479] Código 511171 processado com sucesso.
# [69480] Processando código 511163 com `analisar_texto_arg_linguistica`...
# [69480] Código 511163 processado com sucesso.
# [69481] Processando código 511136 com `analisar_texto_arg_linguistica`...
# [69481] Código 511136 processado com sucesso.
# [69482] Processando código 510882 com `analisar_texto_arg_linguistica`...
# [69482] Código 510882 processado com sucesso.
# [69483] Processando código 512664 com `analisar_texto_arg_linguistica`...
# [69483] Código 512664 processado com sucesso.
# Salvando progresso após 2135 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69484] Processando código 512645 com `analisar_texto_arg_linguistica`...
# [69484] Código 512645 processado com sucesso.
# [69485] Processando código 512529 com `analisar_texto_arg_linguistica`...
# [69485] Código 512529 processado com sucesso.
# [69486] Processando código 512480 com `analisar_texto_arg_linguistica`...
# [69486] Código 512480 processado com sucesso.
# [69487] Processando código 512257 com `analisar_texto_arg_linguistica`...
# [69487] Código 512257 processado com sucesso.
# [69488] Processando código 511915 com `analisar_texto_arg_linguistica`...
# [69488] Código 511915 processado com sucesso.
# Salvando progresso após 2140 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69489] Processando código 511732 com `analisar_texto_arg_linguistica`...
# [69489] Código 511732 processado com sucesso.
# [69490] Processando código 510667 com `analisar_texto_arg_linguistica`...
# [69490] Código 510667 processado com sucesso.
# [69491] Processando código 511337 com `analisar_texto_arg_linguistica`...
# [69491] Código 511337 processado com sucesso.
# [69492] Processando código 511328 com `analisar_texto_arg_linguistica`...
# [69492] Código 511328 processado com sucesso.
# [69493] Processando código 511323 com `analisar_texto_arg_linguistica`...
# [69493] Código 511323 processado com sucesso.
# Salvando progresso após 2145 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69494] Processando código 511320 com `analisar_texto_arg_linguistica`...
# [69494] Código 511320 processado com sucesso.
# [69495] Processando código 511303 com `analisar_texto_arg_linguistica`...
# [69495] Código 511303 processado com sucesso.
# [69496] Processando código 511281 com `analisar_texto_arg_linguistica`...
# [69496] Código 511281 processado com sucesso.
# [69497] Processando código 511250 com `analisar_texto_arg_linguistica`...
# [69497] Código 511250 processado com sucesso.
# [69498] Processando código 511170 com `analisar_texto_arg_linguistica`...
# [69498] Código 511170 processado com sucesso.
# Salvando progresso após 2150 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69499] Processando código 511180 com `analisar_texto_arg_linguistica`...
# [69499] Código 511180 processado com sucesso.
# [69500] Processando código 511129 com `analisar_texto_arg_linguistica`...
# [69500] Código 511129 processado com sucesso.
# [69501] Processando código 511111 com `analisar_texto_arg_linguistica`...
# [69501] Código 511111 processado com sucesso.
# [69502] Processando código 511100 com `analisar_texto_arg_linguistica`...
# [69502] Código 511100 processado com sucesso.
# [69503] Processando código 511087 com `analisar_texto_arg_linguistica`...
# [69503] Código 511087 processado com sucesso.
# Salvando progresso após 2155 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69504] Processando código 511082 com `analisar_texto_arg_linguistica`...
# [69504] Código 511082 processado com sucesso.
# [69505] Processando código 511044 com `analisar_texto_arg_linguistica`...
# [69505] Código 511044 processado com sucesso.
# [69506] Processando código 510971 com `analisar_texto_arg_linguistica`...
# [69506] Código 510971 processado com sucesso.
# [69507] Processando código 512037 com `analisar_texto_arg_linguistica`...
# [69507] Código 512037 processado com sucesso.
# [69508] Processando código 512443 com `analisar_texto_arg_linguistica`...
# [69508] Código 512443 processado com sucesso.
# Salvando progresso após 2160 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69509] Processando código 512424 com `analisar_texto_arg_linguistica`...
# [69509] Código 512424 processado com sucesso.
# [69510] Processando código 512394 com `analisar_texto_arg_linguistica`...
# [69510] Código 512394 processado com sucesso.
# [69511] Processando código 512392 com `analisar_texto_arg_linguistica`...
# [69511] Código 512392 processado com sucesso.
# [69512] Processando código 512390 com `analisar_texto_arg_linguistica`...
# [69512] Código 512390 processado com sucesso.
# [69513] Processando código 510951 com `analisar_texto_arg_linguistica`...
# [69513] Código 510951 processado com sucesso.
# Salvando progresso após 2165 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# [69514] Processando código 511952 com `analisar_texto_arg_linguistica`...
# [69514] Código 511952 processado com sucesso.
# [69515] Processando código 512162 com `analisar_texto_arg_linguistica`...
# [69515] Código 512162 processado com sucesso.
# [69516] Processando código 512152 com `analisar_texto_arg_linguistica`...
# [69516] Código 512152 processado com sucesso.
# [69517] Processando código 512273 com `analisar_texto_arg_linguistica`...
# [69517] Código 512273 processado com sucesso.
# [69518] Processando código 512219 com `analisar_texto_arg_linguistica`...
# [69518] Código 512219 processado com sucesso.
# Salvando progresso após 2170 iterações no arquivo resultados_arg_linguistica.json...
# Progresso salvo com sucesso!
# Salvando o progresso final no arquivo resultados_arg_linguistica.json...
# Processamento concluído. Resultados salvos com sucesso!

# %% [markdown]
# #### Atualizando xlsx

# %%
import pandas as pd
import json

# Insira os caminhos dos seus arquivos locais
xlsx_path = '../../data/dados_analisados_2025-05-03.xlsx'
json_path_1 = 'resultados_parciais.json'
json_path_2 = 'resultados_arg_linguistica.json'
output_path = '../../data/dados_analisados_2025-05-03_2.xlsx'

# Carregar todas as planilhas originais
excel_data = pd.ExcelFile(xlsx_path)
sheet_names = excel_data.sheet_names

# Carregar a planilha AnaliseCorpusTodo para modificação
df_analise = excel_data.parse('AnaliseCorpusTodo')

# Carregar e ajustar JSON resultados_parciais.json
with open(json_path_1, 'r', encoding='utf-8') as f:
    json_data_1 = json.load(f)
df_json_1 = pd.DataFrame.from_dict(json_data_1, orient='index')
df_json_1.index = df_json_1.index.astype(df_analise.index.dtype)

# Carregar e ajustar JSON resultados_arg_linguistica.json
with open(json_path_2, 'r', encoding='utf-8') as f:
    json_data_2 = json.load(f)
df_json_2 = pd.DataFrame.from_dict(json_data_2, orient='index')
df_json_2.index = df_json_2.index.astype(df_analise.index.dtype)

# Combinar os dados originais com os JSONs, garantindo inclusão de novas linhas
df_analise = df_json_1.combine_first(df_analise)
df_analise = df_json_2.combine_first(df_analise)
df_analise.reset_index(inplace=True)

def normalize_dataframe(df):
    """
    Normaliza um DataFrame removendo caracteres inválidos de strings.

    Parâmetros:
    - df (pd.DataFrame): DataFrame a ser normalizado.

    Retorna:
    - pd.DataFrame: Um novo DataFrame com os valores normalizados.
    """

    def clean_value(value):
        # Se for string, remove caracteres não imprimíveis (abaixo de 32) e substitui espaços extras.
        if isinstance(value, str):
            # Remove caracteres ASCII não imprimíveis
            value = re.sub(r"[\x00-\x1F]+", "", value)
            # Remove espaços extras desnecessários
            return value.strip()
        return value

    # Aplica a função de limpeza célula a célula no DataFrame
    return df.applymap(clean_value)



# Criar novo arquivo Excel com as planilhas preservadas e a modificada
with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
    for sheet in sheet_names:
        if sheet != 'AnaliseCorpusTodo':
            temp_df = excel_data.parse(sheet)
            temp_df.to_excel(writer, sheet_name=sheet, index=False)

    # Normalizar o DataFrame
    df_analise_normalizado = normalize_dataframe(df_analise)

    # Adicionar a planilha modificada
    df_analise_normalizado.to_excel(writer, sheet_name='AnaliseCorpusTodo', index=False)

print(f'Novo arquivo Excel criado com sucesso: {output_path}')
# Out:
# /var/folders/2k/hh_m8b1d5mn22m0sk7d_zncc0000gn/T/ipykernel_28115/4209742206.py:55: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(clean_value)
# Novo arquivo Excel criado com sucesso: ../../data/dados_analisados_2025-05-03_2.xlsx

# %% [markdown]
# Verificando integridade do banco de dados

# %%
import pandas as pd

# Caminho do arquivo Excel
caminho_arquivo = '../../data/dados_analisados_2025-05-03_2.xlsx'

# Carregar planilhas
df_discursos = pd.read_excel(caminho_arquivo, sheet_name='Discursos')
df_analise_corpus_todo = pd.read_excel(caminho_arquivo, sheet_name='AnaliseCorpusTodo')

# Verificar se as colunas relevantes estão presentes
if 'CodigoPronunciamento' not in df_discursos.columns:
    raise KeyError("A coluna 'CodigoPronunciamento' não está presente na planilha 'Discursos'.")
if 'CodigoPronunciamento' not in df_analise_corpus_todo.columns:
    raise KeyError("A coluna 'CodigoPronunciamento' não está presente na planilha 'AnaliseCorpusTodo'.")

# Verificar se todos os discursos estão presentes
faltantes = df_discursos[~df_discursos['CodigoPronunciamento'].isin(df_analise_corpus_todo['CodigoPronunciamento'])]

# Exibir resultados da verificação
if faltantes.empty:
    print("Todos os discursos da planilha 'Discursos' estão presentes na planilha 'AnaliseCorpusTodo'.")
else:
    print(f"Existem {len(faltantes)} discursos ausentes na planilha 'AnaliseCorpusTodo'.")
    print("Esses discursos ausentes são:")
    print(faltantes)

# Remover o índice da planilha 'AnaliseCorpusTodo'
df_analise_corpus_todo.reset_index(inplace=True, drop=True)
# Out:
# Todos os discursos da planilha 'Discursos' estão presentes na planilha 'AnaliseCorpusTodo'.

# %% [markdown]
# ##### Para facilitar o trabalho de análise, resolvi deixar para trabalhar com XLSX quando for criar gráficos no Tableau! #####

# %%
import os
import pandas as pd
import csv  # Biblioteca para controle avançado sobre o formato CSV

# Caminho para o arquivo Excel e o diretório onde serão salvos os CSVs
caminho_arquivo_excel = '../../data/dados_analisados_2025-05-03_2.xlsx'
diretorio_saida = '../../data/temp'

# Criar o diretório de saída, caso ainda não exista
if not os.path.exists(diretorio_saida):
    os.makedirs(diretorio_saida)
    print(f"Diretório '{diretorio_saida}' criado com sucesso.")

# Abrir o arquivo Excel e salvar cada planilha como CSV
excel_data = pd.ExcelFile(caminho_arquivo_excel)  # Carregar o arquivo Excel
for sheet_name in excel_data.sheet_names:
    df = excel_data.parse(sheet_name)  # Carregar a planilha como DataFrame
    caminho_csv = os.path.join(diretorio_saida, f"{sheet_name}.csv")  # Definir o caminho do CSV
    df.to_csv(
        caminho_csv,
        index=False,  # Não salvar índice do DataFrame
        encoding='utf-8',  # Garantir que a codificação seja UTF-8
        sep=',',  # Separador padrão: vírgula
        quoting=csv.QUOTE_ALL,  # Envolver todas as células em aspas
    )
    print(f"Planilha '{sheet_name}' salva como CSV em: {caminho_csv}")

print("Todas as planilhas foram convertidas para arquivos CSV em 'data/temp'.")
# Out:
# Planilha 'Discursos' salva como CSV em: ../../data/temp/Discursos.csv
# Planilha 'Senadores' salva como CSV em: ../../data/temp/Senadores.csv
# Planilha 'PesquisaSemantica' salva como CSV em: ../../data/temp/PesquisaSemantica.csv
# Planilha 'AnaliseAnual' salva como CSV em: ../../data/temp/AnaliseAnual.csv
# Planilha 'TopicosCorpusTodo' salva como CSV em: ../../data/temp/TopicosCorpusTodo.csv
# Planilha 'AnaliseCorpusTodo' salva como CSV em: ../../data/temp/AnaliseCorpusTodo.csv
# Todas as planilhas foram convertidas para arquivos CSV em 'data/temp'.

# %% [markdown]
# ##### Limpeza de textos ####

# %%
import pandas as pd
import re

# Caminho para o arquivo CSV
caminho_csv_discursos = '../../data/temp/Discursos.csv'

# Carregar o arquivo CSV
df_discursos = pd.read_csv(caminho_csv_discursos, encoding='utf-8')

# Lista de padrões e substituições
substituicoes = {
    r"\bComissão de Constituição, Justiça e Cidadania\b": "CCJC",
    r"\bComissão de Constituição e Justiça\b": "CCJ",
    r"\bProposta de Emenda à Constituição\b": "PEC",
    r"\bPropostas de Emenda à Constituição\b": "PEC",
}


# Função para remover acentos e aplicar substituições
def substituir_expressao(texto, substituicoes):


    # Substituir expressões conforme os padrões listados
    for padrao, substituto in substituicoes.items():
        texto = re.sub(padrao, substituto, texto, flags=re.IGNORECASE)
    return texto


# Aplicar a substituição em todas as células do DataFrame
df_discursos = df_discursos.applymap(
    lambda x: substituir_expressao(x, substituicoes) if isinstance(x, str) else x
)

# Salvar o arquivo atualizado
df_discursos.to_csv(caminho_csv_discursos, index=False, encoding='utf-8', quoting=1)

print(f"As expressões foram substituídas e o arquivo atualizado foi salvo em: {caminho_csv_discursos}")
# Out:
# /var/folders/2k/hh_m8b1d5mn22m0sk7d_zncc0000gn/T/ipykernel_28115/1216596194.py:30: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_discursos = df_discursos.applymap(
# As expressões foram substituídas e o arquivo atualizado foi salvo em: ../../data/temp/Discursos.csv

# %% [markdown]
# #### TF-IDF e BM25 Corpus Todo ####

# %%
# !pip install scikit-learn rank-bm25
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/25/92/ee1d7a00bb6b8c55755d4984fd82608603a3cc59959245068ce32e7fb808/scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Using cached scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting rank-bm25
#   Obtaining dependency information for rank-bm25 from https://files.pythonhosted.org/packages/2a/21/f691fb2613100a62b3fa91e9988c991e9ca5b89ea31c0d3152a3210344f9/rank_bm25-0.2.2-py3-none-any.whl.metadata
#   Using cached rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/pedblan/PycharmProjects/falando_nela/.venv/lib/python3.11/site-packages (from scikit-learn) (2.2.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Obtaining dependency information for scipy>=1.6.0 from https://files.pythonhosted.org/packages/61/d8/84da3fffefb6c7d5a16968fe5b9f24c98606b165bb801bb0b8bc3985200f/scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl.metadata
#   Using cached scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/da/d3/13ee227a148af1c693654932b8b0b02ed64af5e1f7406d56b088b57574cd/joblib-1.5.0-py3-none-any.whl.metadata
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/32/d5/f9a850d79b0851d1d4ef6456097579a9005b31fea68726a4ae5f2d82ddd9/threadpoolctl-3.6.0-py3-none-any.whl.metadata
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl (11.1 MB)
# Using cached rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Using cached scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl (22.4 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, rank-bm25, joblib, scikit-learn
# Successfully installed joblib-1.5.0 rank-bm25-0.2.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from rank_bm25 import BM25Okapi
import re

# Caminhos dos arquivos
caminho_csv_discursos = '../../data/temp/Discursos.csv'  # Arquivo de entrada
caminho_csv_saida = '../../data/temp/AnaliseCorpusTodo.csv'  # Arquivo de saída (já existente)

# Carregar o arquivo de saída existente
df_saida = pd.read_csv(caminho_csv_saida, encoding='utf-8')

# Verificar a presença da coluna "BM25_CorpusTodo_Constituicao"
if 'BM25_CorpusTodo_Constituição' not in df_saida.columns:
    raise KeyError("A coluna 'BM25_CorpusTodo_Constituicao' não foi encontrada em AnaliseCorpusTodo.csv.")

# Carregar o arquivo de entrada (discursos) e pré-processar os textos
df_discursos = pd.read_csv(caminho_csv_discursos, encoding='utf-8')

# Verificar a presença da coluna "TextoIntegral"
if 'TextoIntegral' not in df_discursos.columns:
    raise KeyError("A coluna 'TextoIntegral' não foi encontrada no arquivo Discursos.csv.")

# Pré-processamento e remoção de acentos, preservando letras maiúsculas
from unidecode import unidecode  # Certifique-se de instalar a biblioteca unidecode


def preprocessar_texto(texto):
    texto = re.sub(r'[^\w\s]', '', texto, flags=re.UNICODE)  # Remove pontuações
    texto = unidecode(texto)  # Remove acentos, mantendo maiúsculas
    return texto


# Preenchendo valores NaN e aplicando pré-processamento
df_discursos['TextoIntegral'] = df_discursos['TextoIntegral'].fillna('')
df_discursos['Texto_Tratado'] = df_discursos['TextoIntegral'].apply(preprocessar_texto)

# Calcular BM25 para a palavra "constituição"
palavra_alvo = 'Constituicao'  # Sem acento, pré-processada

# Preparar documentos tokenizados
documentos_tokenizados = [doc.split() for doc in df_discursos['Texto_Tratado']]
bm25 = BM25Okapi(documentos_tokenizados)
bm25_scores = bm25.get_scores([palavra_alvo])  # Obter os escores para a palavra

# Atualizar a coluna "BM25_CorpusTodo_Constituicao" no DataFrame do arquivo de saída
if len(df_saida) != len(bm25_scores):
    raise ValueError("Os tamanhos dos DataFrames 'Discursos.csv' e 'AnaliseCorpusTodo.csv' não coincidem.")

df_saida['BM25_CorpusTodo_Constituição'] = bm25_scores

# Salvar as alterações no arquivo de saída, preservando as demais colunas
df_saida.to_csv(caminho_csv_saida, index=False, encoding='utf-8', quoting=1)

print(f"A coluna 'BM25_CorpusTodo_Constituicao' foi atualizada com sucesso em: {caminho_csv_saida}")
# Out:
# A coluna 'BM25_CorpusTodo_Constituicao' foi atualizada com sucesso em: ../../data/temp/AnaliseCorpusTodo.csv

# %% [markdown]
# #### Análise Anual ####

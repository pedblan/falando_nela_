# %% [markdown]
# 1. Definir textos a serem vetorizados

# %%
db_path = "./DiscursosSenadores_02_05_2025_analisado.sqlite"


import sqlite3
import pandas as pd


conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# Query para encontrar os códigos dos pronunciamentos
cursor.execute("""
    SELECT CodigoPronunciamento
    FROM Discursos
    WHERE LOWER(TextoIntegral) LIKE '%constitui%'
""")
codigos_pronunciamentos = [row[0] for row in cursor.fetchall()]

# Query para obter os dados desejados
query = f"""
    SELECT
        d.CodigoPronunciamento,
        d.Indexacao,
        da.SumarioConstituicao,
        da.TrechosConstituicao,
        da.NormPredicacao,
        da.NormImplicacao,
        da.NormConclusao,
        da.NormTrecho,
        da.AvalPredicacao,
        da.AvalImplicacao,
        da.AvalConclusao,
        da.AvalTrecho
    FROM Discursos d
    JOIN AnaliseCorpusTodo da ON d.CodigoPronunciamento = da.CodigoPronunciamento
    WHERE d.CodigoPronunciamento IN ({','.join(['?'] * len(codigos_pronunciamentos))})
"""

cursor.execute(query, codigos_pronunciamentos)
results = cursor.fetchall()

# Criar um DataFrame do Pandas
df = pd.DataFrame(results, columns=['CodigoPronunciamento', 'Indexacao', 'SumarioConstituicao', 'TrechosConstituicao', 'NormPredicacao', 'NormImplicacao', 'NormConclusao', 'NormTrecho', 'AvalPredicacao', 'AvalImplicacao', 'AvalConclusao', 'AvalTrecho'])

conn.close()

# %% [markdown]
# 2. Fazer os embeddings

# %%
# !pip install faiss-cpu openai
import time
import random
import numpy as np
import faiss
import os
from openai import OpenAI
# Configurar a API da OpenAI
api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)

# Definir a pasta onde os arquivos FAISS serão salvos
faiss_pasta = "../data/discursos/embeddings"

# Criar a pasta se não existir
os.makedirs(faiss_pasta, exist_ok=True)

# Definir as colunas de texto para gerar embeddings
colunas_embeddings = ['Indexacao', 'SumarioConstituicao', 'TrechosConstituicao', 'NormPredicacao', 'NormImplicacao', 'NormConclusao', 'NormTrecho', 'AvalPredicacao', 'AvalImplicacao', 'AvalConclusao', 'AvalTrecho']

# Parâmetros do FAISS
embedding_dim = 3072  # Ajuste conforme o modelo
lote_tamanho = 100  # Número de embeddings processados antes de salvar no FAISS
checkpoint_tamanho = 500  # Checkpoint para salvar o progresso

def carregar_codigos_existentes(nome_arquivo):
    """Carrega os códigos já processados para evitar duplicação."""
    caminho_codigos = os.path.join(faiss_pasta, nome_arquivo)
    if os.path.exists(caminho_codigos):
        return set(np.load(caminho_codigos))  # Convertendo para set para busca rápida
    return set()

def criar_ou_carregar_faiss(nome_arquivo):
    """Cria um índice FAISS ou carrega um existente."""
    caminho_faiss = os.path.join(faiss_pasta, nome_arquivo)
    try:
        index = faiss.read_index(caminho_faiss)
        print(f"✅ Índice FAISS carregado de '{caminho_faiss}'.")
    except:
        index = faiss.IndexFlatL2(embedding_dim)
        print(f"📂 Criando novo índice FAISS '{caminho_faiss}'.")
    return index, caminho_faiss

def salvar_progresso(faiss_index, caminho_faiss, codigos_existentes, caminho_codigos):
    """Salva o índice FAISS e atualiza os códigos já processados."""
    faiss.write_index(faiss_index, caminho_faiss)
    np.save(caminho_codigos, np.array(list(codigos_existentes), dtype=np.int32))
    print(f"💾 Progresso salvo! Índice '{caminho_faiss}' atualizado.")

def gerar_embedding(texto):
    """Gera um embedding usando a API da OpenAI."""
    response = client.embeddings.create(input=texto, model="text-embedding-3-large")
    return np.array(response.data[0].embedding, dtype=np.float32).reshape(1, -1)

def processar_embeddings(df, coluna, lote_tamanho=100, checkpoint_tamanho=500):
    """
    Processa os textos de uma coluna do DataFrame, gera embeddings e armazena em FAISS.

    Args:
        df (pd.DataFrame): DataFrame contendo os discursos.
        coluna (str): Nome da coluna a ser processada.
        lote_tamanho (int): Quantidade de embeddings processados antes de salvar no FAISS.
        checkpoint_tamanho (int): Quantidade de discursos processados antes de salvar o progresso.

    Returns:
        None
    """
    nome_faiss = f"discursos_{coluna}.index"
    nome_codigos = f"codigos_{coluna}.npy"

    faiss_index, caminho_faiss = criar_ou_carregar_faiss(nome_faiss)
    caminho_codigos = os.path.join(faiss_pasta, nome_codigos)

    # Carregar códigos já processados para evitar duplicação
    codigos_existentes = carregar_codigos_existentes(nome_codigos)
    buffer = []
    codigos_novos = []
    total_processados = 0  # Contador para checkpoints

    for i, row in df.iterrows():
        codigo = int(row["CodigoPronunciamento"])
        texto = str(row[coluna]).strip()  # Converter para string e remover espaços extras

        if not texto:
            print(f"⚠️ Texto vazio para CodigoPronunciamento {codigo}. Pulando...")
            continue

        if codigo in codigos_existentes:
            print(f"🔄 {coluna}: CodigoPronunciamento {codigo} já processado. Pulando...")
            continue

        try:
            embedding = gerar_embedding(texto)
            buffer.append(embedding)
            codigos_novos.append(codigo)
            print(f"[{i+1}/{len(df)}] {coluna}: Texto {codigo} processado.")

            # Adicionar ao FAISS quando atingir o tamanho do lote
            if len(buffer) >= lote_tamanho:
                batch = np.vstack(buffer)
                faiss_index.add(batch)
                buffer.clear()
                total_processados += lote_tamanho
                print(f"✅ {lote_tamanho} embeddings adicionados ao FAISS.")

            # Salvar progresso em checkpoints regulares
            if total_processados >= checkpoint_tamanho:
                codigos_existentes.update(codigos_novos)
                salvar_progresso(faiss_index, caminho_faiss, codigos_existentes, caminho_codigos)
                codigos_novos.clear()
                total_processados = 0  # Reset do contador de checkpoint

        except Exception as e:
            print(f"❌ Erro ao processar CodigoPronunciamento {codigo}: {str(e)}")

        # Pequena pausa para evitar sobrecarga da API
        time.sleep(random.uniform(0.5, 1.5))

    # Salvar os embeddings restantes no FAISS
    if buffer:
        batch = np.vstack(buffer)
        faiss_index.add(batch)
        print("✅ Buffer final de embeddings salvo no FAISS.")

    # Salvar o progresso final
    codigos_existentes.update(codigos_novos)
    salvar_progresso(faiss_index, caminho_faiss, codigos_existentes, caminho_codigos)

    print(f"🚀 Processamento concluído para '{coluna}'!")

# Processar embeddings para cada coluna
for coluna in colunas_embeddings:
    processar_embeddings(df, coluna, lote_tamanho, checkpoint_tamanho)
# Out:
# Requirement already satisfied: faiss-cpu in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (1.11.0)
# Requirement already satisfied: openai in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (1.77.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from faiss-cpu) (2.2.5)
# Requirement already satisfied: packaging in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/pedblan/PycharmProjects/falando_nela_/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ✅ Índice FAISS carregado de '../data/discursos/embeddings/discursos_Indexacao.index'.
# 🔄 Indexacao: CodigoPronunciamento 366329 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366331 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366333 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366336 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366337 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366400 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366406 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366407 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366410 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366419 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366421 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366425 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366427 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366434 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366436 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366439 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366440 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366444 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366446 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366455 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366456 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366457 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366458 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366469 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366471 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366472 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366474 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366479 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366480 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366485 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366487 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366492 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366494 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366497 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366500 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366505 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366511 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366515 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366517 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366522 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366526 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366527 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366531 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366534 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366544 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366551 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366555 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366556 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366557 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366559 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366562 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366563 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366565 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366566 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366567 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366568 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366571 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366574 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366578 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366579 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366581 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366583 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366585 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366587 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366590 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366591 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366611 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366617 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366628 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366630 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366633 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366634 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366673 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366676 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366677 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366682 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366683 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366684 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366687 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366693 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366695 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366696 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366697 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366698 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366699 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366703 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366704 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366708 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366710 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366711 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366715 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366717 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366721 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366722 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366725 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366726 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366737 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366741 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366743 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366744 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366746 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366749 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366751 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366765 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366770 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366772 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366779 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366781 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366787 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366793 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366806 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366813 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366836 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366837 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366839 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366840 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366841 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366843 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366845 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366847 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366851 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366852 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366855 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366858 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366859 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366863 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366864 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366866 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366887 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366889 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366890 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366891 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366901 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366904 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366930 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366934 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366939 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366945 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366952 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366958 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366959 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366960 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366961 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366963 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366969 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366992 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366993 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366994 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 366997 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367005 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367007 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367015 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367018 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367019 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367020 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367022 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367024 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367032 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367034 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367058 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367067 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367072 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367075 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367077 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367084 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367086 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367090 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367091 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367092 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367098 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367100 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367101 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367102 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367104 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367107 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367112 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367113 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367117 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367127 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367135 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367136 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367139 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367145 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367146 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367150 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367152 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367153 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367159 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367192 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367234 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367244 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367247 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367248 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367250 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367255 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367261 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367262 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367263 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367267 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367272 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367278 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367279 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367281 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367282 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367285 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367288 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367293 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367298 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367301 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367311 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367326 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367338 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367341 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367343 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367344 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367345 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367348 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367349 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367355 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367367 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367370 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367377 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367378 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367379 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367380 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367383 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367386 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367387 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367389 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367393 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367395 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 367400 já processado. Pulando...
# 🔄 Indexacao: CodigoPronunciamento 